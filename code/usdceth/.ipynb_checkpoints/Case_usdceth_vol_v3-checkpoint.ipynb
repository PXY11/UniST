# %%
import os
import sys
import talib as ta
syspath = os.path.split(os.path.abspath("."))[0]
sys.path.append(syspath)
import univ3api.simulation as sim
import univ3api.utils as utils
import importlib
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# run if simulation file is updated
importlib.reload(sim)

HOST = "mongodb://172.16.11.81:27017/ETHDATA"
source = sim.DataUtilMongoDB(HOST)

from datetime import datetime
import time
d1 = datetime(2021,5,10, 9)
d2 = datetime(2021,11,10,9)
t1 = int(time.mktime(d1.timetuple()))
t2 = int(time.mktime(d2.timetuple()))

# print(d1.timetuple())
# print(time.mktime(d1.timetuple()))
# print(int(time.mktime(d1.timetuple())))

# swapdata = source.swap_by_time("SWAP_WETH_USDT_3000", t1, t2)
swapdata = source.swap_by_time("SWAP_USDC_WETH_500", t1, t2)
swapdata.tail()
pricedata = swapdata[["timestamp", "sqrtPriceX96"]]
# pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(18, 6).x96_to_price)
pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(6, 18).x96_to_price)

# %%
pricedata_res = pd.read_csv('../../data/usdceth/pricedata_res2021051020211110v3.csv',index_col=0) 
pricedata_res.dropna(axis=0,how='any',inplace=True)
pricedata_res
# Out:
#                       timestamp                        sqrtPriceX96     price  \
# datetime
# 2021-05-10 23:01:26  1620687686  1250336482323975592868676385759397  0.000249
# 2021-05-10 23:04:55  1620687895  1250606199335176904167975195585904  0.000249
# 2021-05-10 23:07:30  1620688050  1251545435079739017905414801047527  0.000250
# 2021-05-10 23:08:41  1620688121  1251879429216418004995325977658334  0.000250
# 2021-05-10 23:09:58  1620688198  1252597668315200797853368028893693  0.000250
# ...                         ...                                 ...       ...
# 2021-11-09 07:06:11  1636441571  1142082588585671647785500155330124  0.000208
# 2021-11-09 07:06:11  1636441571  1142071759175866417828744621024494  0.000208
# 2021-11-09 07:06:52  1636441612  1142000969568059491037541876247525  0.000208
# 2021-11-09 07:06:52  1636441612  1142013920888200672190989935421715  0.000208
# 2021-11-09 07:06:52  1636441612  1141931602527976500544381270562450  0.000208
#
#                     SmaLowerLma VolLowerBelowmaQuantile50 CloseLowerMA  \
# datetime
# 2021-05-10 23:01:26       False                     False        False
# 2021-05-10 23:04:55       False                     False        False
# 2021-05-10 23:07:30       False                     False        False
# 2021-05-10 23:08:41       False                     False        False
# 2021-05-10 23:09:58       False                     False        False
# ...                         ...                       ...          ...
# 2021-11-09 07:06:11        True                      True        False
# 2021-11-09 07:06:11        True                      True        False
# 2021-11-09 07:06:52        True                      True        False
# 2021-11-09 07:06:52        True                      True        False
# 2021-11-09 07:06:52        True                      True        False
#
#                     VolHigherOvermaQuantile50Twosigma revoke_pos
# datetime
# 2021-05-10 23:01:26                             False       True
# 2021-05-10 23:04:55                             False       True
# 2021-05-10 23:07:30                             False       True
# 2021-05-10 23:08:41                             False       True
# 2021-05-10 23:09:58                             False       True
# ...                                               ...        ...
# 2021-11-09 07:06:11                             False      False
# 2021-11-09 07:06:11                             False      False
# 2021-11-09 07:06:52                             False      False
# 2021-11-09 07:06:52                             False      False
# 2021-11-09 07:06:52                             False      False
#
# [828249 rows x 8 columns]

# %%
init_price = pricedata_res["price"][0]

decimal0 = 6 #USDC的精度
decimal1 = 18 #ETH的精度

init_amount0 = 1000000*1e6 #初始持有USDC的数量
init_amount1 = 0 #初始持有ETH的数量
print('init_price =',init_price)
# Out:
# init_price = 0.0002490546409686298

# %%
import Strategy_usdceth_vol_v2
importlib.reload(utils)
importlib.reload(sim)
importlib.reload(Strategy_usdceth_vol_v2)
strategy = Strategy_usdceth_vol_v2.HoldStrategy(init_amount0, init_amount1, decimal0, decimal1, sim.PoolFee.low, True)
strategy.init(swapdata.iloc[0].to_dict())

# strategy.run(swapdata, priceDt)
strategy.run(swapdata, pricedata_res)

report = strategy.report()
# Out:
# **********************【Price Over MA】【创建Long Vol池子】【第1次建池】***********************************
# 转换后钱包中余额 amount0:  449725000000.0 amount1:  131740588200586870784
# price:  0.0002490546409686298
# $$$$$$$【Upper Price】: 0.00032115384728466525
# $$$$$$$【Lower Price】: 0.00019314174409697279
# ######【L】:60425157395093728【USDC】:449725000000【ETH】:116281437364565458944
# 将要投入池子的数量 amount_t0: 449725000000 amount_t1: 116281437364565458944
# 【RealWorldTime】:2021-05-11 06:57:20, Timestamp: 1620687440, Blocknumber: 12409488
# Mint position： Position(L=60267255159050576, tick=[190740, 195840], range=[3127.5344, 5208.1227])
# 【Mint amount】: token0=447330.039568, token1=116.28143736456546
# Wallet amount: token0=2394.960432, token1=15.459150836021411
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: True
# Price(0.0002377688143629313) out of range(0.00019314174409697279, 0.00032115384728466525)
# 【RealWorldTime】:2021-05-13 06:59:25,Timestamp: 1620860365, Blocknumber: 12422393
# Decreased position： Position(L=0, tick=[190740, 195840], range=[3127.5344, 5208.1227])
# 【Decreased amount】: token0=527695.340433, token1=96.66717626163735
# Wallet amount: token0=530090.300865, token1=112.12632709765877
# 撤池后经转换 Wallet amount: token0=925884.200849, token1=5.56885646597576
# **********************【Price Over MA】【创建Long Vol池子】【第2次建池】***********************************
# 转换后钱包中余额 amount0:  416393272228.0 amount1:  184383133634974306685
# price:  0.00035215449028785115
# $$$$$$$【Upper Price】: 0.00045410022858702277
# $$$$$$$【Lower Price】: 0.00027309562343928815
# ######【L】:66128527943046800【USDC】:416393272228【ETH】:150448427174147457024
# 将要投入池子的数量 amount_t0: 416393272227 amount_t1: 150448427174147719168
# 【RealWorldTime】:2021-06-04 06:59:28, Timestamp: 1622761168, Blocknumber: 12564357
# Mint position： Position(L=66111163882731552, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Mint amount】: token0=416171.751456, token1=150.44842717414772
# Wallet amount: token0=221.520772, token1=33.93470646082659
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.0003668542997974856) out of range(0.00027309562343928815, 0.00045410022858702277)
# 【RealWorldTime】:2021-06-05 06:59:58,Timestamp: 1622847598, Blocknumber: 12570861
# Decreased position： Position(L=0, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Decreased amount】: token0=347179.99125, token1=175.2294636147207
# Wallet amount: token0=347401.512022, token1=209.16417007554725
# 撤池后经转换 Wallet amount: token0=883629.257721, token1=10.385907839298628
# **********************【Price Over MA】【创建Long Vol池子】【第3次建池】***********************************
# 转换后钱包中余额 amount0:  397390167930.0 amount1:  234020238020717505001
# price:  0.0004605331861196576
# $$$$$$$【Upper Price】: 0.0005938536376972077
# $$$$$$$【Lower Price】: 0.0003571432454972405
# ######【L】:71715814449242624【USDC】:397390167930【ETH】:185432775995937095680
# 将要投入池子的数量 amount_t0: 397390167930 amount_t1: 185432775995937095680
# 【RealWorldTime】:2021-07-25 06:59:25, Timestamp: 1627167565, Blocknumber: 12891838
# Mint position： Position(L=71688212911412088, tick=[196920, 202020], range=[1685.8601, 2807.3764])
# 【Mint amount】: token0=397082.246994, token1=185.4327759959371
# Wallet amount: token0=307.920936, token1=48.58746202478041
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.00035662473667513804) out of range(0.0003571432454972405, 0.0005938536376972077)
# 【RealWorldTime】:2021-08-05 22:41:34,Timestamp: 1628174494, Blocknumber: 12965558
# Decreased position： Position(L=0, tick=[196920, 202020], range=[1685.8601, 2807.3764])
# 【Decreased amount】: token0=845130.596503, token1=3.494064473515814
# Wallet amount: token0=845438.517439, token1=52.08152649829622
# 撤池后经转换 Wallet amount: token0=999474.05605, token1=2.731825015375262
# **********************【Price Over MA】【创建Long Vol池子】【第4次建池】***********************************
# 转换后钱包中余额 amount0:  449488469858.0 amount1:  199396740450250027596
# price:  0.0003570299543330797
# $$$$$$$【Upper Price】: 0.00046038709812430006
# $$$$$$$【Lower Price】: 0.0002768765432620034
# ######【L】:72364954490140000【USDC】:449488469858【ETH】:163250917780722515968
# 将要投入池子的数量 amount_t0: 449488469858 amount_t1: 163250917780722515968
# 【RealWorldTime】:2021-08-05 22:41:34, Timestamp: 1628174494, Blocknumber: 12965558
# Mint position： Position(L=71508354108661600, tick=[194400, 199440], range=[2182.0460, 3611.9138])
# 【Mint amount】: token0=438762.884541, token1=163.25091778072252
# Wallet amount: token0=10725.585317, token1=36.14582266952751
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.00027673829225134693) out of range(0.0002768765432620034, 0.00046038709812430006)
# 【RealWorldTime】:2021-09-02 00:31:13,Timestamp: 1630513873, Blocknumber: 13140847
# Decreased position： Position(L=0, tick=[194400, 199440], range=[2182.0460, 3611.9138])
# 【Decreased amount】: token0=952131.387173, token1=1.4243270187386992
# Wallet amount: token0=962856.97249, token1=37.57014968826621
# 撤池后经转换 Wallet amount: token0=1125695.63474, token1=2.1169295463772047
# **********************【Price Over MA】【创建Long Vol池子】【第5次建池】***********************************
# 转换后钱包中余额 amount0:  506253469334.0 amount1:  173282731547324781548
# price:  0.00027673745623920466
# $$$$$$$【Upper Price】: 0.0003568506027967844
# $$$$$$$【Lower Price】: 0.00021460975289246676
# ######【L】:71007821859864096【USDC】:506253469334【ETH】:142691479109389402112
# 将要投入池子的数量 amount_t0: 506253469333 amount_t1: 142691479109389402112
# 【RealWorldTime】:2021-09-02 00:31:39, Timestamp: 1630513899, Blocknumber: 13140849
# Mint position： Position(L=70991738552030016, tick=[191820, 196920], range=[2807.3764, 4674.9799])
# 【Mint amount】: token0=506022.011537, token1=142.6914791093894
# Wallet amount: token0=231.457797, token1=30.59125243793538
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00033451971816897066) out of range(0.00021460975289246676, 0.0003568506027967844)
# 【RealWorldTime】:2021-09-21 06:59:44,Timestamp: 1632178784, Blocknumber: 13265491
# Decreased position： Position(L=0, tick=[191820, 196920], range=[2807.3764, 4674.9799])
# 【Decreased amount】: token0=120149.809044, token1=260.09264920996753
# Wallet amount: token0=120381.266841, token1=290.6839016479029
# 撤池后经转换 Wallet amount: token0=984200.677099, token1=14.719201330253368
# **********************【Price Over MA】【创建Long Vol池子】【第6次建池】***********************************
# 转换后钱包中余额 amount0:  442619649509.0 amount1:  179265211740080179358
# price:  0.0003042154017637858
# $$$$$$$【Upper Price】: 0.00039228318050895484
# $$$$$$$【Lower Price】: 0.00023591888530685804
# ######【L】:64779801213150904【USDC】:442619649509【ETH】:135842068494777434112
# 将要投入池子的数量 amount_t0: 442619649508 amount_t1: 135842068494777319424
# 【RealWorldTime】:2021-10-02 06:59:26, Timestamp: 1633129166, Blocknumber: 13336303
# Mint position： Position(L=64772862336138664, tick=[192780, 197880], range=[2550.4127, 4247.0714])
# 【Mint amount】: token0=442619.649508, token1=135.81309512000675
# Wallet amount: token0=1e-06, token1=43.45211662007344
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.00023590861935724903) out of range(0.00023591888530685804, 0.00039228318050895484)
# 【RealWorldTime】:2021-10-21 09:21:55,Timestamp: 1634779315, Blocknumber: 13458020
# Decreased position： Position(L=0, tick=[192780, 197880], range=[2550.4127, 4247.0714])
# 【Decreased amount】: token0=942643.728929, token1=1.7551947114425972
# Wallet amount: token0=942643.72893, token1=45.20731133151603
# 撤池后经转换 Wallet amount: token0=1148738.722977, token1=2.396040591335515
# **********************【Price Over MA】【创建Long Vol池子】【第7次建池】***********************************
# 转换后钱包中余额 amount0:  516616522192.0 amount1:  151257933645795091376
# price:  0.00023592052134219
# $$$$$$$【Upper Price】: 0.00030421751141747105
# $$$$$$$【Lower Price】: 0.00018295624118097457
# ######【L】:67506265806093808【USDC】:516616522192【ETH】:126344128732696428544
# 将要投入池子的数量 amount_t0: 516616522192 amount_t1: 126344128732696428544
# 【RealWorldTime】:2021-10-21 09:22:19, Timestamp: 1634779339, Blocknumber: 13458023
# Mint position： Position(L=67500999800128280, tick=[190200, 195300], range=[3301.0555, 5497.0785])
# 【Mint amount】: token0=516534.443663, token1=126.34412873269643
# Wallet amount: token0=82.078529, token1=24.913804913098662

# %%
positions = report.positions
positions
# Out:
# {1: <univ3api.simulation.PositionReport at 0x1bd15310710>,
#  2: <univ3api.simulation.PositionReport at 0x1bdcc271e10>,
#  3: <univ3api.simulation.PositionReport at 0x1bdcc289d30>,
#  4: <univ3api.simulation.PositionReport at 0x1bdcc2892b0>,
#  5: <univ3api.simulation.PositionReport at 0x1bdcc27c358>,
#  6: <univ3api.simulation.PositionReport at 0x1bdcc27c908>,
#  7: <univ3api.simulation.PositionReport at 0x1bdcc27cda0>}

# %%
positions[5].get_balance(plain=True, draw_plot=True)
# Out:
#                  datetime        amount0          fee0       cumFee0  \
# 0     2021-09-02 00:31:39  506022.011537      0.000000      0.000000
# 1     2021-09-02 00:31:41  506028.457495      0.003222      0.003222
# 2     2021-09-02 00:31:42  504945.192109      0.000000      0.003222
# 3     2021-09-02 00:31:42  509715.031891      2.384919      2.388141
# 4     2021-09-02 00:31:45  512199.828494      1.242398      3.630539
# ...                   ...            ...           ...           ...
# 82744 2021-09-21 06:59:18  117891.873716      0.355722  22194.110032
# 82745 2021-09-21 06:59:27  120659.848901      1.383987  22195.494019
# 82746 2021-09-21 06:59:44  120553.261876      0.000000  22195.494019
# 82747 2021-09-21 06:59:44  120149.809044      0.000000  22195.494019
# 82748 2021-09-21 06:59:44       0.000000 -22195.494019  22195.494019
#
#        collectedFee0  amount1      fee1   cumFee1  collectedFee1
# 0           0.000000  142.691  0.000000  0.000000       0.000000
# 1           0.003222   142.69  0.000000  0.000000       0.000000
# 2           0.003222   142.99  0.000150  0.000150       0.000150
# 3           2.388141   141.67  0.000000  0.000150       0.000150
# 4           3.630539  140.984  0.000000  0.000150       0.000150
# ...              ...      ...       ...       ...            ...
# 82744   22194.110032  260.848  0.000000  6.523511       6.523511
# 82745   22195.494019  259.922  0.000000  6.523511       6.523511
# 82746   22195.494019  259.958  0.000018  6.523529       6.523529
# 82747   22195.494019  260.093  0.000067  6.523596       6.523596
# 82748       0.000000        0 -6.523596  6.523596       0.000000
#
# [82749 rows x 9 columns]

# %%
total_balance = report.total_balance(draw_plot=True, plain=True)

# %%
price = pricedata.drop_duplicates("timestamp").set_index("timestamp")["price"]
price
usdc_balance = total_balance.set_index("timestamp")[["amount0", "cumFee0"]].sum(axis=1)
eth_balance = total_balance.set_index("timestamp")[["amount1", "cumFee1"]].sum(axis=1) / price
eth_balance+usdc_balance
# eth_balance.plot()
# usdt_balance.plot()
tb_Timing = (eth_balance+usdc_balance)
tb_Timing_origin = tb_Timing.copy(deep=True)
time_to_print = list(map(time.localtime,tb_Timing.index.tolist()))
time_to_print_2  = [time.strftime('%Y-%m-%d %H:%M:%S', i) for i in time_to_print]
# time_to_print_2  = [time.strftime('%Y-%m-%d', i) for i in time_to_print]
tb_Timing.index = time_to_print_2
tb_Timing.plot(rot = 45,grid=True)
# tb_Timing.to_csv('../../data/usdceth/tb_timing_v2.csv')
# tb_Timing_origin.to_csv('../../data/usdceth/tb_timing_origin_v2.csv')
# Out:
# <AxesSubplot:>

# %%
eth_balance
eth_balance_df = pd.DataFrame(eth_balance)
eth_balance_df.columns = ['eth_balance']
eth_balance_df
# Out:
#               eth_balance
# timestamp
# 1620608620       0.000000
# 1620608625       0.000000
# 1620608735       0.000000
# 1620609459       0.000000
# 1620609550       0.000000
# ...                   ...
# 1636441469  474862.412254
# 1636441482  474845.280292
# 1636441498  474817.294768
# 1636441571  474736.456011
# 1636441612  474229.578600
#
# [509255 rows x 1 columns]

# %%
usdc_balance
usdc_balance_df = pd.DataFrame(usdc_balance)
usdc_balance_df.columns = ['usdc_balance']
usdc_balance_df
# Out:
#               usdc_balance
# timestamp
# 1620608620  1000000.000000
# 1620608625  1000000.000000
# 1620608735  1000000.000000
# 1620609459  1000000.000000
# 1620609550  1000000.000000
# ...                    ...
# 1636441469   847820.175668
# 1636441482   847846.074929
# 1636441498   847876.845178
# 1636441571   847967.020359
# 1636441612   848542.214640
#
# [509255 rows x 1 columns]

# %%
tb_Timing
tb_Timing_df = pd.DataFrame(tb_Timing)
tb_Timing_df.columns = ['total_balance']
tb_Timing_df
# Out:
#                      total_balance
# 2021-05-10 09:03:40   1.000000e+06
# 2021-05-10 09:03:45   1.000000e+06
# 2021-05-10 09:05:35   1.000000e+06
# 2021-05-10 09:17:39   1.000000e+06
# 2021-05-10 09:19:10   1.000000e+06
# ...                            ...
# 2021-11-09 15:04:29   1.322683e+06
# 2021-11-09 15:04:42   1.322691e+06
# 2021-11-09 15:04:58   1.322694e+06
# 2021-11-09 15:06:11   1.322703e+06
# 2021-11-09 15:06:52   1.322772e+06
#
# [509255 rows x 1 columns]

# %%
pd.to_datetime(tb_Timing_df.index.tolist()[0])
# Out:
# Timestamp('2021-05-10 09:03:40')

# %%
tb_Timing_df_day = tb_Timing_df.copy(deep=True)
tb_Timing_df_day = 
tb_Timing_df_day = tb_Timing_df.resample('D').sum()
tb_Timing_df_day
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e05e2a5e7b41> in <module>()
# ----> 1 tb_Timing_df_day = tb_Timing_df.resample('D').sum()
#       2 tb_Timing_df_day
#
# C:\SoftWare Install\Anaconda\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8094             level=level,
#    8095             origin=origin,
# -> 8096             offset=offset,
#    8097         )
#    8098
#
# C:\SoftWare Install\Anaconda\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# C:\SoftWare Install\Anaconda\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1434
#    1435         raise TypeError(
# -> 1436             "Only valid with DatetimeIndex, "
#    1437             "TimedeltaIndex or PeriodIndex, "
#    1438             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
