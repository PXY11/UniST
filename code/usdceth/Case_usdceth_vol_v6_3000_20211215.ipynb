# %% [markdown]
# # 获取原始数据

# %%
import os
import sys
import talib as ta
syspath = os.path.split(os.path.abspath("."))[0]
sys.path.append(syspath)
import univ3api.simulation as sim
import univ3api.utils as utils
import importlib
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import pickle
import talib as ta
from dateutil.parser import parse
import numpy as np
# run if simulation file is updated
importlib.reload(sim)

HOST = "mongodb://172.16.20.88:27017/ETHDATA"
source = sim.DataUtilMongoDB(HOST)

from datetime import datetime
import time
d1 = datetime(2021,5,10, 9)
d2 = datetime(2021,12,14,9)
t1 = int(time.mktime(d1.timetuple()))
t2 = int(time.mktime(d2.timetuple()))

# print(d1.timetuple())
# print(time.mktime(d1.timetuple()))
# print(int(time.mktime(d1.timetuple())))

# swapdata = source.swap_by_time("SWAP_WETH_USDT_3000", t1, t2)
swapdata = source.swap_by_time("SWAP_USDC_WETH_3000", t1, t2)
swapdata.tail()
pricedata = swapdata[["timestamp", "sqrtPriceX96"]]
# pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(18, 6).x96_to_price)
pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(6, 18).x96_to_price)
pricedata['datetime']  = pd.to_datetime(pricedata['timestamp'],unit='s')
pricedata['datetime'] = [str(tmp)[:] for tmp in pricedata['datetime'].tolist()]
pricedata
# Out:
#          timestamp                        sqrtPriceX96     price  \
# 0       1620609472  1267554519342589161168659854845874  0.000256
# 1       1620609830  1267498129839936824485169221023868  0.000256
# 2       1620609889  1267496927736336268048970777338285  0.000256
# 3       1620609889  1267496466129159558106023913391909  0.000256
# 4       1620609894  1267269382521328460205280017540103  0.000256
# ...            ...                                 ...       ...
# 170540  1639441705  1284826478296620672637866660000000  0.000263
# 170541  1639441705  1284807669206505310394689313819347  0.000263
# 170542  1639441911  1284798012002724167961825097254885  0.000263
# 170543  1639441943  1283662307917943862180387397292362  0.000263
# 170544  1639442093  1282087987831672062469146442482499  0.000262
#
#                    datetime
# 0       2021-05-10 01:17:52
# 1       2021-05-10 01:23:50
# 2       2021-05-10 01:24:49
# 3       2021-05-10 01:24:49
# 4       2021-05-10 01:24:54
# ...                     ...
# 170540  2021-12-14 00:28:25
# 170541  2021-12-14 00:28:25
# 170542  2021-12-14 00:31:51
# 170543  2021-12-14 00:32:23
# 170544  2021-12-14 00:34:53
#
# [170545 rows x 4 columns]

# %%
pricedata['datetime'].tolist()[0]
# Out:
# '2021-05-10 01:17:52'

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
#之后要扩展回测区间时，需要更新此处的基本行情数据
df_eth = load_obj('../../data/usdceth/symbolsData_2018032120211116_60min_v16_E')['60min']
df_eth
# Out:
#                                eth
#                               open     high      low    close       volume
# timestamp
# 2018-03-21 12:00:00+00:00   580.19   581.44   570.00   573.58   4203.57962
# 2018-03-21 13:00:00+00:00   573.36   578.27   570.73   573.13   3038.19939
# 2018-03-21 14:00:00+00:00   573.12   578.50   571.57   575.50   3057.08944
# 2018-03-21 15:00:00+00:00   575.50   584.41   574.00   574.73   4885.99445
# 2018-03-21 16:00:00+00:00   575.00   577.48   556.02   556.62  11892.60047
# ...                            ...      ...      ...      ...          ...
# 2021-11-10 04:00:00+00:00  4691.48  4717.33  4677.91  4713.75  10383.83280
# 2021-11-10 05:00:00+00:00  4713.76  4716.44  4697.30  4701.07   7720.72120
# 2021-11-10 06:00:00+00:00  4701.08  4740.96  4697.28  4739.78  11182.21750
# 2021-11-10 07:00:00+00:00  4739.79  4743.92  4708.43  4714.60  11782.47300
# 2021-11-10 08:00:00+00:00  4714.60  4735.70  4708.23  4720.12   8804.61560
#
# [31917 rows x 5 columns]

# %% [markdown]
# # 指标计算

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
#之后要扩展回测区间时，需要更新此处的基本行情数据
df_eth = load_obj('../../data/usdceth/symbolsData_2018032120211215_60min_v16_E')['60min']
df_eth.columns= ['open','high','low','close','volume']
df_eth = df_eth.loc['2018-03-22':'2021-12-14']
df_eth.reset_index(inplace=True)
df_eth.columns = ['datetime','open','high','low','close','volume']
def cal_indicator(dataCoin):    
    dataCoin['pctChange'] = dataCoin['close'].pct_change()
    dataCoin['pctStd'] = ta.STDDEV(dataCoin['pctChange'], 24*5)*(24**0.5)
    dataCoin['pctStdVma'] = ta.SUM(dataCoin['pctStd']*dataCoin['volume'], 24*50) / ta.SUM(dataCoin['volume'], 24*50)
    dataCoin['closeVma'] = ta.SUM(dataCoin['close']*dataCoin['volume'], 24*50) / ta.SUM(dataCoin['volume'], 24*50)
    dataCoin['pctStdVSma'] = ta.EMA(dataCoin.pctStdVma, 24*3)
    dataCoin['pctStdVLma'] = ta.MA(dataCoin.pctStdVma, 24*10)
    dataCoin['SmaLowerLma'] = dataCoin['pctStdVSma']<dataCoin['pctStdVLma']
    dataCoin['CloseLowerMA'] = dataCoin['close'] < dataCoin['closeVma']
    #根据volResearch notebook里的BelowMA的vol stat中quantile50的2018.5至2021.5波动率统计得出
    dataCoin['VolLowerBelowmaQuantile50'] = dataCoin['pctStd'] < 0.035857 
    #根据volResearch notebook里的OverMA的vol stat中quantile50的2018.5至2021.5波动率统计得出
    dataCoin['VolHigherOvermaQuantile50Twosigma'] = dataCoin['pctStd'] > (0.038511 + 2*0.018451)
    #当波动率高于Belowma的vol stat中的Quantile50的1.05倍时撤销池子
    dataCoin['revoke_pos'] = dataCoin['pctStd'] > 0.035857 *1.05
    
cal_indicator(df_eth)

df_eth_test_period = df_eth[df_eth['datetime']>parse('2021-05-10 00:00:00+00:00')]
df_signal_tmp = df_eth_test_period[['datetime',
                               'SmaLowerLma',
                               'VolLowerBelowmaQuantile50',
                               'CloseLowerMA',
                               'VolHigherOvermaQuantile50Twosigma',
                               'revoke_pos']]
df_signal_tmp['timestamp'] = [0]*len(df_signal_tmp)
df_signal_tmp['sqrtPriceX96'] = [0]*len(df_signal_tmp)
df_signal_tmp['price'] = [0]*len(df_signal_tmp)

df_signal_tmp = df_signal_tmp[['timestamp','sqrtPriceX96','price','datetime',
                 'SmaLowerLma',
                 'VolLowerBelowmaQuantile50',
                 'CloseLowerMA',
                 'VolHigherOvermaQuantile50Twosigma',
                 'revoke_pos']]
df_signal_tmp['datetime_2'] = df_signal_tmp['datetime']
df_signal_tmp = df_signal_tmp.set_index('datetime_2')
# df_signal_tmp = df_signal_tmp.resample('D').first()
df_signal_tmp['datetime'] = [str(tmp)[:-6] for tmp in df_signal_tmp['datetime'].tolist()]
df_signal_tmp['ind'] = [i for i in range(len(pricedata),len(pricedata)+len(df_signal_tmp))]
df_signal_tmp.set_index('ind',inplace=True)
pricedata_tmp = pricedata.append(df_signal_tmp)
pricedata_tmp = pricedata_tmp.sort_values(by='datetime')
pricedata_tmp_beforefill = pricedata_tmp.copy(deep = True)
pricedata_tmp = pricedata_tmp.fillna(method = 'ffill')
pricedata_res = pricedata_tmp.loc[pricedata.index]
pricedata_res.set_index('datetime',inplace=True)
pricedata_res
# Out:
#                       timestamp                        sqrtPriceX96     price  \
# datetime
# 2021-05-10 01:17:52  1620609472  1267554519342589161168659854845874  0.000256
# 2021-05-10 01:23:50  1620609830  1267498129839936824485169221023868  0.000256
# 2021-05-10 01:24:49  1620609889  1267496927736336268048970777338285  0.000256
# 2021-05-10 01:24:49  1620609889  1267496466129159558106023913391909  0.000256
# 2021-05-10 01:24:54  1620609894  1267269382521328460205280017540103  0.000256
# ...                         ...                                 ...       ...
# 2021-12-14 00:28:25  1639441705  1284826478296620672637866660000000  0.000263
# 2021-12-14 00:28:25  1639441705  1284807669206505310394689313819347  0.000263
# 2021-12-14 00:31:51  1639441911  1284798012002724167961825097254885  0.000263
# 5   -0.004211     NaN        NaN       NaN         NaN         NaN
# 6   -0.002819     NaN        NaN       NaN         NaN         NaN
# 7   -0.005283     NaN        NaN       NaN         NaN         NaN
# 8    0.005293     NaN        NaN       NaN         NaN         NaN
# 9   -0.031820     NaN        NaN       NaN         NaN         NaN
# 10  -0.012646     NaN        NaN       NaN         NaN         NaN
# 11  -0.009352     NaN        NaN       NaN         NaN         NaN
# 12   0.009963     NaN        NaN       NaN         NaN         NaN
# 13  -0.022777     NaN        NaN       NaN         NaN         NaN
# 14  -0.022212     NaN        NaN       NaN         NaN         NaN
# 15   0.026602     NaN        NaN       NaN         NaN         NaN
# 16  -0.001620     NaN        NaN       NaN         NaN         NaN
# 17   0.013336     NaN        NaN       NaN         NaN         NaN
# 18  -0.005026     NaN        NaN       NaN         NaN         NaN
# 19  -0.005388     NaN        NaN       NaN         NaN         NaN
# 20  -0.006527     NaN        NaN       NaN         NaN         NaN
# 21   0.004790     NaN        NaN       NaN         NaN         NaN
# 22   0.014698     NaN        NaN       NaN         NaN         NaN
# 23   0.002637     NaN        NaN       NaN         NaN         NaN
# 24  -0.009187     NaN        NaN       NaN         NaN         NaN
# 25  -0.008206     NaN        NaN       NaN         NaN         NaN
# 26  -0.025539     NaN        NaN       NaN         NaN         NaN
# 27  -0.003520     NaN        NaN       NaN         NaN         NaN
# 28   0.002271     NaN        NaN       NaN         NaN         NaN
# 29   0.005190     NaN        NaN       NaN         NaN         NaN
# 30  -0.006030     NaN        NaN       NaN         NaN         NaN
# 31  -0.005660     NaN        NaN       NaN         NaN         NaN
# 32   0.015341     NaN        NaN       NaN         NaN         NaN
# 33   0.002285     NaN        NaN       NaN         NaN         NaN
# 34  -0.003563     NaN        NaN       NaN         NaN         NaN
# 35   0.007324     NaN        NaN       NaN         NaN         NaN
# 36  -0.027767     NaN        NaN       NaN         NaN         NaN
# 37   0.011228     NaN        NaN       NaN         NaN         NaN
# 38   0.021022     NaN        NaN       NaN         NaN         NaN
# 39  -0.000475     NaN        NaN       NaN         NaN         NaN
# 40   0.000456     NaN        NaN       NaN         NaN         NaN
# 41  -0.000380     NaN        NaN       NaN         NaN         NaN
# 42  -0.004564     NaN        NaN       NaN         NaN         NaN
# 43   0.005522     NaN        NaN       NaN         NaN         NaN
# 44  -0.003648     NaN        NaN       NaN         NaN         NaN
# 45   0.009783     NaN        NaN       NaN         NaN         NaN
# 46   0.000623     NaN        NaN       NaN         NaN         NaN
# 47   0.024914     NaN        NaN       NaN         NaN         NaN
# 48   0.000737     NaN        NaN       NaN         NaN         NaN
# 49  -0.015513     NaN        NaN       NaN         NaN         NaN
#
#     SmaLowerLma  CloseLowerMA  VolLowerBelowmaQuantile50  \
# 0         False         False                      False
# 1         False         False                      False
# 2         False         False                      False
# 3         False         False                      False
# 4         False         False                      False
# 5         False         False                      False
# 6         False         False                      False
# 7         False         False                      False
# 8         False         False                      False
# 9         False         False                      False
# 10        False         False                      False
# 11        False         False                      False
# 12        False         False                      False
# 13        False         False                      False
# 14        False         False                      False
# 15        False         False                      False
# 16        False         False                      False
# 17        False         False                      False
# 18        False         False                      False
# 19        False         False                      False
# 20        False         False                      False
# 21        False         False                      False
# 22        False         False                      False
# 23        False         False                      False
# 24        False         False                      False
# 25        False         False                      False
# 26        False         False                      False
# 27        False         False                      False
# 28        False         False                      False
# 29        False         False                      False
# 30        False         False                      False
# 31        False         False                      False
# 32        False         False                      False
# 33        False         False                      False
# 34        False         False                      False
# 35        False         False                      False
# 36        False         False                      False
# 37        False         False                      False
# 38        False         False                      False
# 39        False         False                      False
# 40        False         False                      False
# 41        False         False                      False
# 42        False         False                      False
# 43        False         False                      False
# 44        False         False                      False
# 45        False         False                      False
# 46        False         False                      False
# 47        False         False                      False
# 48        False         False                      False
# 49        False         False                      False
#
#     VolHigherOvermaQuantile50Twosigma  revoke_pos
# 0                               False       False
# 1                               False       False
# 2                               False       False
# 3                               False       False
# 4                               False       False
# 5                               False       False
# 6                               False       False
# 7                               False       False
# 8                               False       False
# 9                               False       False
# 10                              False       False
# 11                              False       False
# 12                              False       False
# 13                              False       False
# 14                              False       False
# 15                              False       False
# 16                              False       False
# 17                              False       False
# 18                              False       False
# 19                              False       False
# 20                              False       False
# 21                              False       False
# 22                              False       False
# 23                              False       False
# 24                              False       False
# 25                              False       False
# 26                              False       False
# 27                              False       False
# 28                              False       False
# 29                              False       False
# 30                              False       False
# 31                              False       False
# 32                              False       False
# 33                              False       False
# 34                              False       False
# 35                              False       False
# 36                              False       False
# 37                              False       False
# 38                              False       False
# 39                              False       False
# 40                              False       False
# 41                              False       False
# 42                              False       False
# 43                              False       False
# 44                              False       False
# 45                              False       False
# 46                              False       False
# 47                              False       False
# 48                              False       False
# 49                              False       False

# %%
df_eth
# Out:
#                        datetime     open     high      low    close  \
# 0     2018-03-22 00:00:00+00:00   559.15   571.51   557.93   570.72
# 1     2018-03-22 01:00:00+00:00   570.72   575.96   565.89   572.78
# 2     2018-03-22 02:00:00+00:00   573.57   577.00   572.32   573.83
# 3     2018-03-22 03:00:00+00:00   574.50   578.60   568.00   569.58
# 4     2018-03-22 04:00:00+00:00   569.33   571.00   565.59   570.00
# ...                         ...      ...      ...      ...      ...
# 32731 2021-12-14 19:00:00+00:00  3747.94  3783.00  3746.84  3768.74
# 32732 2021-12-14 20:00:00+00:00  3768.74  3857.01  3768.06  3833.95
# 32733 2021-12-14 21:00:00+00:00  3834.37  3882.74  3828.50  3851.29
# 32734 2021-12-14 22:00:00+00:00  3851.03  3862.71  3819.74  3838.22
# 32735 2021-12-14 23:00:00+00:00  3838.22  3875.00  3820.00  3858.99
#
#             volume  pctChange    pctStd  pctStdVma     closeVma  pctStdVSma  \
# 0       4373.76732        NaN       NaN        NaN          NaN         NaN
# 1       3352.67170   0.003609       NaN        NaN          NaN         NaN
# 2       2939.72257   0.001833       NaN        NaN          NaN         NaN
# 3       4051.97864  -0.007406       NaN        NaN          NaN         NaN
# 4       2229.88027   0.000737       NaN        NaN          NaN         NaN
# ...            ...        ...       ...        ...          ...         ...
# 32731   8531.65990   0.005547  0.043616   0.038733  4305.841935    0.038558
# 32732  22149.38070   0.017303  0.044347   0.038740  4305.446581    0.038563
# 32733  19338.22750   0.004523  0.044155   0.038746  4305.106148    0.038568
# 32734   9314.72970  -0.003394  0.044169   0.038750  4304.958310    0.038573
# 32735  10681.77440   0.005411  0.043796   0.038753  4304.774492    0.038578
#
#        pctStdVLma  SmaLowerLma  CloseLowerMA  VolLowerBelowmaQuantile50  \
# 0             NaN        False         False                      False
# 1             NaN        False         False                      False
# 2             NaN        False         False                      False
# 3             NaN        False         False                      False
# 4             NaN        False         False                      False
# ...           ...          ...           ...                        ...
# 32731    0.037980        False          True                      False
# 32732    0.037988        False          True                      False
# 32733    0.037996        False          True                      False
# 32734    0.038004        False          True                      False
# 32735    0.038012        False          True                      False
#
#        VolHigherOvermaQuantile50Twosigma  revoke_pos
# 0                                  False       False
# 1                                  False       False
# 2                                  False       False
# 3                                  False       False
# 4                                  False       False
# ...                                  ...         ...
# 32731                              False        True
# 32732                              False        True
# 32733                              False        True
# 32734                              False        True
# 32735                              False        True
#
# [32736 rows x 17 columns]

# %% [markdown]
# # 回测

# %%
init_price = pricedata_res["price"][0]

decimal0 = 6 #USDC的精度
decimal1 = 18 #ETH的精度

init_amount0 = 1000000*1e6 #初始持有USDC的数量
init_amount1 = 0 #初始持有ETH的数量
print('init_price =',init_price)
# Out:
# init_price = 0.0002559611947100053

# %% [markdown]
# # 建池撤池详细信息

# %%
import Strategy_usdceth_vol_v2
importlib.reload(utils)
importlib.reload(sim)
importlib.reload(Strategy_usdceth_vol_v2)
strategy = Strategy_usdceth_vol_v2.HoldStrategy(init_amount0, init_amount1, decimal0, decimal1, sim.PoolFee.low, True)
strategy.init(swapdata.iloc[0].to_dict())

# strategy.run(swapdata, priceDt)
strategy.run(swapdata, pricedata_res)

report = strategy.report()
# Out:
# **********************【Price Over MA】【创建Long Vol池子】【第1次建池】***********************************
# 转换后钱包中余额 amount0:  449725000000.0 amount1:  193767622941744726016
# price:  0.0003524863942496469
# $$$$$$$【Upper Price】: 0.000454528215930865
# $$$$$$$【Lower Price】: 0.00027335301478845
# ######【L】:71725449612659512【USDC】:449725000000【ETH】:163855038906967031808
# 将要投入池子的数量 amount_t0: 449724999999 amount_t1: 163855038906967031808
# 【RealWorldTime】:2021-06-03 16:50:54, Timestamp: 1622710254, Blocknumber: 12560564
# Mint position： Position(L=71647907245445792, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Mint amount】: token0=449724.999999, token1=163.50654018568494
# Wallet amount: token0=1e-06, token1=30.261082756059793
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00034722516869073754) out of range(0.00027335301478845, 0.000454528215930865)
# 【RealWorldTime】:2021-06-03 18:48:59,Timestamp: 1622717339, Blocknumber: 12561107
# Decreased position： Position(L=0, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Decreased amount】: token0=477332.045873, token1=153.84783869811687
# Wallet amount: token0=477332.045874, token1=184.10892145417665
# 撤池后经转换 Wallet amount: token0=980737.554348, token1=9.11806998351148
# **********************【Price Over MA】【创建Long Vol池子】【第2次建池】***********************************
# 转换后钱包中余额 amount0:  441062196630.0 amount1:  199112033193447590356
# price:  0.00035234281698993356
# $$$$$$$【Upper Price】: 0.00045434307427215024
# $$$$$$$【Lower Price】: 0.00027324167069847096
# ######【L】:70194757104022920【USDC】:441062196630【ETH】:160028797977089409024
# 将要投入池子的数量 amount_t0: 441062196629 amount_t1: 160028797977089409024
# 【RealWorldTime】:2021-06-04 06:52:40, Timestamp: 1622760760, Blocknumber: 12564328
# Mint position： Position(L=70164428222407200, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Mint amount】: token0=440675.380178, token1=160.0287979770894
# Wallet amount: token0=386.816452, token1=39.08323521635818
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00035002028520071004) out of range(0.00027324167069847096, 0.00045434307427215024)
# 【RealWorldTime】:2021-06-04 07:57:40,Timestamp: 1622764660, Blocknumber: 12564592
# Decreased position： Position(L=0, tick=[194220, 199320], range=[2208.3870, 3677.5136])
# 【Decreased amount】: token0
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.00035854920365500833) out of range(0.0003585769834940505, 0.0005962376405746104)
# 【RealWorldTime】:2021-08-05 22:40:10,Timestamp: 1628174410, Blocknumber: 12965554
# Decreased position： Position(L=0, tick=[196980, 202020], range=[1685.8601, 2790.5834])
# 【Decreased amount】: token0=949379.591324, token1=2.0417124551358747
# Wallet amount: token0=950245.116387, token1=55.88697733398747
# 撤池后经转换 Wallet amount: token0=1101375.285529, token1=2.798277184235067
# **********************【Price Over MA】【创建Long Vol池子】【第6次建池】***********************************
# 转换后钱包中余额 amount0:  495316000286.0 amount1:  219868650238454715891
# price:  0.00035830166271823
# $$$$$$$【Upper Price】: 0.00046202695530153144
# $$$$$$$【Lower Price】: 0.00027786275245102074
# ######【L】:79139131240217888【USDC】:495316000286【ETH】:181152054362640285696
# 将要投入池子的数量 amount_t0: 495316000285 amount_t1: 181152054362640285696
# 【RealWorldTime】:2021-08-05 22:41:34, Timestamp: 1628174494, Blocknumber: 12965558
# Mint position： Position(L=78890771442760528, tick=[194400, 199500], range=[2168.9936, 3611.9138])
# 【Mint amount】: token0=492175.395608, token1=181.15205436264029
# Wallet amount: token0=3140.604678, token1=38.71659587581443
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.000277432219764514) out of range(0.00027786275245102074, 0.00046202695530153144)
# 【RealWorldTime】:2021-09-02 00:31:37,Timestamp: 1630513897, Blocknumber: 13140848
# Decreased position： Position(L=0, tick=[194400, 199500], range=[2168.9936, 3611.9138])
# 【Decreased amount】: token0=1055971.239951, token1=3.098198293702471
# Wallet amount: token0=1059111.844629, token1=41.8147941695169
# 撤池后经转换 Wallet amount: token0=1209406.13637, token1=2.1255627416125056
# **********************【Price Over MA】【创建Long Vol池子】【第7次建池】***********************************
# 转换后钱包中余额 amount0:  543900174680.0 amount1:  186549590316180826588
# price:  0.00027679293620883804
# $$$$$$$【Upper Price】: 0.0003569221437470984
# $$$$$$$【Lower Price】: 0.0002146527775799641
# ######【L】:76352573373413392【USDC】:543900174680【ETH】:153558864684953010176
# 将要投入池子的数量 amount_t0: 543900174680 amount_t1: 153558864684952748032
# 【RealWorldTime】:2021-09-02 00:31:41, Timestamp: 1630513901, Blocknumber: 13140851
# Mint position： Position(L=75614334613766512, tick=[191820, 196920], range=[2807.3764, 4674.9799])
# 【Mint amount】: token0=533283.296567, token1=153.55886468495274
# Wallet amount: token0=10616.878113, token1=32.99072563122808
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.0003110871643479762) out of range(0.0002146527775799641, 0.0003569221437470984)
# 【RealWorldTime】:2021-09-20 10:59:57,Timestamp: 1632106797, Blocknumber: 13260108
# Decreased position： Position(L=0, tick=[191820, 196920], range=[2807.3764, 4674.9799])
# 【Decreased amount】: token0=280744.545819, token1=227.7483479902776
# Wallet amount: token0=291361.423932, token1=260.7390736215057
# 撤池后经转换 Wallet amount: token0=1093857.382518, token1=12.968123887175915
# **********************【Price Over MA】【创建Long Vol池子】【第8次建池】***********************************
# 转换后钱包中余额 amount0:  491935011354.0 amount1:  198877801030348560530
# price:  0.000309104608455279
# $$$$$$$【Upper Price】: 0.00039858777107203836
# $$$$$$$【Lower Price】: 0.00023971046254457964
# ######【L】:73634264223889616【USDC】:491935011354【ETH】:157860695448271618048
# 将要投入池子的数量 amount_t0: 491935011354 amount_t1: 157860695448271618048
# 【RealWorldTime】:2021-10-01 23:59:35, Timestamp: 1633103975, Blocknumber: 13334433
# Mint position： Position(L=73432301875403344, tick=[192900, 198000], range=[2519.9921, 4196.4137])
# 【Mint amount】: token0=489185.37347, token1=157.86069544827163
# Wallet amount: token0=2749.637884, token1=41.017105582076944
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00030318240641838293) out of range(0.00023971046254457964, 0.00039858777107203836)
# 【RealWorldTime】:2021-10-02 10:58:16,Timestamp: 1633143496, Blocknumber: 13337326
# Decreased position： Position(L=0, tick=[192900, 198000], range=[2519.9921, 4196.4137])
# 【Decreased amount】: token0=532825.328921, token1=144.5028591480541
# Wallet amount: token0=535574.966805, token1=185.51996473013105
# 撤池后经转换 Wallet amount: token0=1117088.880243, token1=9.188723338336548
# **********************【Price Over MA】【创建Long Vol池子】【第9次建池】***********************************
# 转换后钱包中余额 amount0:  502382796668.0 amount1:  196720262274487498226
# price:  0.00030550478009641423
# $$$$$$$【Upper Price】: 0.0003939458229335996
# $$$$$$$【Lower Price】: 0.00023691879753092322
# ######【L】:74843874994523680【USDC】:502382796668【ETH】:156239974947720331264
# 将要投入池子的数量 amount_t0: 502382796667 amount_t1: 156239974947720331264
# 【RealWorldTime】:2021-10-02 11:53:35, Timestamp: 1633146815, Blocknumber: 13337587
# Mint position： Position(L=74830566463268336, tick=[192840, 197880], range=[2550.4127, 4221.6666])
# 【Mint amount】: token0=502202.522924, token1=156.23997494772033
# Wallet amount: token0=180.273744, token1=40.48028732676717
# ******************************************【撤销池子】【原因:超边撤池】******************************************
# Price(0.00023687755809824676) out of range(0.00023691879753092322, 0.0003939458229335996)
# 【RealWorldTime】:2021-10-21 09:17:51,Timestamp: 1634779071, Blocknumber: 13458004
# Decreased position： Position(L=0, tick=[192840, 197880], range=[2550.4127, 4221.6666])
# 【Decreased amount】: token0=1082070.690174, token1=0.22100991850725196
# Wallet amount: token0=1082250.963918, token1=40.70129724527442
# 撤池后经转换 Wallet amount: token0=1249863.53127, token1=2.0429270068239376
# **********************【Price Over MA】【创建Long Vol池子】【第10次建池】***********************************
# 转换后钱包中余额 amount0:  562094876601.0 amount1:  164770024326749713752
# price:  0.00023650016554420302
# $$$$$$$【Upper Price】: 0.0003049649576999765
# $$$$$$$【Lower Price】: 0.00018340575495713664
# ######【L】:72587981535313760【USDC】:562094876601【ETH】:134308067103111233536
# 将要投入池子的数量 amount_t0: 562094876601 amount_t1: 134308067103111233536
# 【RealWorldTime】:2021-10-21 09:18:22, Timestamp: 1634779102, Blocknumber: 13458005
# Mint position： Position(L=72102974956819968, tick=[190260, 195360], range=[3281.3095, 5464.1964])
# 【Mint amount】: token0=554547.650421, token1=134.30806710311123
# Wallet amount: token0=7547.22618, token1=30.461957223638482
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.0002486835981524838) out of range(0.00018340575495713664, 0.0003049649576999765)
# 【RealWorldTime】:2021-11-19 05:56:22,Timestamp: 1637272582, Blocknumber: 13641854
# Decreased position： Position(L=0, tick=[190260, 195360], range=[3281.3095, 5464.1964])
# 【Decreased amount】: token0=442022.821827, token1=161.61864995763972
# Wallet amount: token0=449570.048007, token1=192.0806071812782
# 撤池后经转换 Wallet amount: token0=1188605.390416, token1=9.550837268073547
# **********************【Price Over MA】【创建Long Vol池子】【第11次建池】***********************************
# 转换后钱包中余额 amount0:  534545559206.0 amount1:  173249465106420631248
# price:  0.0002506838064998879
# $$$$$$$【Upper Price】: 0.00032325464242019135
# $$$$$$$【Lower Price】: 0.00019440516111625047
# ######【L】:72191077531596080【USDC】:534545559206【ETH】:136612324907072143360
# 将要投入池子的数量 amount_t0: 534545559206 amount_t1: 136612324907072143360
# 【RealWorldTime】:2021-11-19 07:57:41, Timestamp: 1637279861, Blocknumber: 13642381
# Mint position： Position(L=72168844076352640, tick=[190860, 195900], range=[3108.8263, 5146.0018])
# 【Mint amount】: token0=534213.087216, token1=136.61232490707212
# Wallet amount: token0=332.47199, token1=36.6371401993485
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.0002468121699214816) out of range(0.00019440516111625047, 0.00032325464242019135)
# 【RealWorldTime】:2021-11-19 09:56:35,Timestamp: 1637286995, Blocknumber: 13642925
# Decreased position： Position(L=0, tick=[190860, 195900], range=[3108.8263, 5146.0018])
# 【Decreased amount】: token0=569925.198512, token1=127.7294396099318
# Wallet amount: token0=570257.670502, token1=164.36657980928032
# 撤池后经转换 Wallet amount: token0=1202222.409036, token1=8.140509373702912
# **********************【Price Over MA】【创建Long Vol池子】【第12次建池】***********************************
# 转换后钱包中余额 amount0:  540669472905.0 amount1:  173446833075375061542
# price:  0.00025018263298809895
# $$$$$$$【Upper Price】: 0.0003226083834272162
# $$$$$$$【Lower Price】: 0.00019401650131940567
# ######【L】:72400265269287024【USDC】:540669472905【ETH】:138885649602183086080
# 将要投入池子的数量 amount_t0: 540669472905 amount_t1: 138885649602183086080
# 【RealWorldTime】:2021-11-19 11:59:46, Timestamp: 1637294386, Blocknumber: 13643443
# Mint position： Position(L=72260646611822736, tick=[190800, 195900], range=[3108.8263, 5176.9691])
# 【Mint amount】: token0=538556.466922, token1=138.8856496021831
# Wallet amount: token0=2113.005983, token1=34.561183473191974
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00024089617523826383) out of range(0.00019401650131940567, 0.0003226083834272162)
# 【RealWorldTime】:2021-11-23 02:59:23,Timestamp: 1637607563, Blocknumber: 13666201
# Decreased position： Position(L=0, tick=[190800, 195900], range=[3108.8263, 5176.9691])
# 【Decreased amount】: token0=627264.044993, token1=117.10664742338437
# Wallet amount: token0=629377.050976, token1=151.66783089657633
# 撤池后经转换 Wallet amount: token0=1227784.579223, token1=7.515154973360296
# **********************【Price Over MA】【创建Long Vol池子】【第13次建池】***********************************
# 转换后钱包中余额 amount0:  552165419892.0 amount1:  173355318100519489602
# price:  0.00024584666926969406
# $$$$$$$【Upper Price】: 0.0003170171949858498
# $$$$$$$【Lower Price】: 0.000190653963718593
# ######【L】:73432631215925488【USDC】:552165419892【ETH】:139891780964553916416
# 将要投入池子的数量 amount_t0: 552165419892 amount_t1: 139891780964553916416
# 【RealWorldTime】:2021-11-23 05:52:44, Timestamp: 1637617964, Blocknumber: 13667008
# Mint position： Position(L=73386044888508368, tick=[190620, 195720], range=[3165.2890, 5270.9935])
# 【Mint amount】: token0=551454.126713, token1=139.8917809645539
# Wallet amount: token0=711.293179, token1=33.463537135965574
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00024401628402393908) out of range(0.000190653963718593, 0.0003170171949858498)
# 【RealWorldTime】:2021-11-23 06:57:51,Timestamp: 1637621871, Blocknumber: 13667281
# Decreased position： Position(L=0, tick=[190620, 195720], range=[3165.2890, 5270.9935])
# 【Decreased amount】: token0=572072.762778, token1=134.8446399301017
# Wallet amount: token0=572784.055957, token1=168.30817706606726
# 撤池后经转换 Wallet amount: token0=1228167.786802, token1=8.335465336244152
# **********************【Price Over MA】【创建Long Vol池子】【第14次建池】***********************************
# 转换后钱包中余额 amount0:  552337757920.0 amount1:  172985306986494665858
# price:  0.00024431015379394223
# $$$$$$$【Upper Price】: 0.00031503587131112944
# $$$$$$$【Lower Price】: 0.00018946239676900914
# ######【L】:73173458205375056【USDC】:552337757920【ETH】:138866128133956714496
# 将要投入池子的数量 amount_t0: 552337757920 amount_t1: 138866128133956714496
# 【RealWorldTime】:2021-11-23 07:46:24, Timestamp: 1637624784, Blocknumber: 13667510
# Mint position： Position(L=72806547979240432, tick=[190560, 195660], range=[3184.3369, 5302.7130])
# 【Mint amount】: token0=552337.75792, token1=137.49359838472466
# Wallet amount: token0=0.0, token1=35.49170860177001
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00023049196253762994) out of range(0.00018946239676900914, 0.00031503587131112944)
# 【RealWorldTime】:2021-11-26 15:51:47,Timestamp: 1637913107, Blocknumber: 13688540
# Decreased position： Position(L=0, tick=[190560, 195660], range=[3184.3369, 5302.7130])
# 【Decreased amount】: token0=688031.390161, token1=105.31887008785468
# Wallet amount: token0=688031.390161, token1=140.8105786896247
# 撤池后经转换 Wallet amount: token0=1269121.823804, token1=6.9778087431363875
# **********************【Price Over MA】【创建Long Vol池子】【第15次建池】***********************************
# 转换后钱包中余额 amount0:  570755812211.0 amount1:  175662080526575723222
# price:  0.00024177343386727786
# $$$$$$$【Upper Price】: 0.0003117647924797394
# $$$$$$$【Lower Price】: 0.00018749517178971947
# ######【L】:75641813830375488【USDC】:570755812211【ETH】:140471401778790039552
# 将要投入池子的数量 amount_t0: 570755812210 amount_t1: 140471401778790039552
# 【RealWorldTime】:2021-11-29 04:39:58, Timestamp: 1638131998, Blocknumber: 13704536
# Mint position： Position(L=75406096390015056, tick=[190500, 195540], range=[3222.7772, 5334.6233])
# 【Mint amount】: token0=567167.1973, token1=140.47140177879007
# Wallet amount: token0=3588.614911, token1=35.19067874778567
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00023176691548165782) out of range(0.00018749517178971947, 0.0003117647924797394)
# 【RealWorldTime】:2021-12-04 02:57:06,Timestamp: 1638557826, Blocknumber: 13735245
# Decreased position： Position(L=0, tick=[190500, 195540], range=[3222.7772, 5334.6233])
# 【Decreased amount】: token0=676760.793602, token1=114.54297271543673
# Wallet amount: token0=680349.408513, token1=149.7336514632224
# 撤池后经转换 Wallet amount: token0=1296354.621677, token1=7.423946487068513
# **********************【Price Over MA】【创建Long Vol池子】【第16次建池】***********************************
# 转换后钱包中余额 amount0:  583003082235.0 amount1:  176528600726764736870
# price:  0.0002372029983617134
# $$$$$$$【Upper Price】: 0.00030587125465739726
# $$$$$$$【Lower Price】: 0.0001839508014403284
# ######【L】:76215327606942336【USDC】:583003082235【ETH】:142720318568300281856
# 将要投入池子的数量 amount_t0: 583003082234 amount_t1: 142720318568300281856
# 【RealWorldTime】:2021-12-07 04:59:01, Timestamp: 1638824341, Blocknumber: 13754509
# Mint position： Position(L=76072119273589680, tick=[190260, 195360], range=[3281.3095, 5464.1964])
# 【Mint amount】: token0=580777.222518, token1=142.72031856830029
# Wallet amount: token0=2225.859717, token1=33.80828215846446
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00023175879349088437) out of range(0.0001839508014403284, 0.00030587125465739726)
# 【RealWorldTime】:2021-12-08 03:49:34,Timestamp: 1638906574, Blocknumber: 13760486
# Decreased position： Position(L=0, tick=[190260, 195360], range=[3281.3095, 5464.1964])
# 【Decreased amount】: token0=641003.388505, token1=128.6014388280664
# Wallet amount: token0=643229.248222, token1=162.40972098653086
# 撤池后经转换 Wallet amount: token0=1309325.276953, token1=8.044510659999744
# **********************【Price Over MA】【创建Long Vol池子】【第17次建池】***********************************
# 转换后钱包中余额 amount0:  588836310178.0 amount1:  176353509209471763509
# price:  0.0002338373284934776
# $$$$$$$【Upper Price】: 0.0003015312519067151
# $$$$$$$【Lower Price】: 0.00018134072621395442
# ######【L】:75777327191334656【USDC】:588836310178【ETH】:139718096920979619840
# 将要投入池子的数量 amount_t0: 588836310178 amount_t1: 139718096920979619840
# 【RealWorldTime】:2021-12-08 06:53:05, Timestamp: 1638917585, Blocknumber: 13761284
# Mint position： Position(L=75748285450031872, tick=[190140, 195240], range=[3320.9204, 5530.1585])
# 【Mint amount】: token0=588381.63279, token1=139.71809692097963
# Wallet amount: token0=454.677388, token1=36.63541228849214
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.000231166247327536) out of range(0.00018134072621395442, 0.0003015312519067151)
# 【RealWorldTime】:2021-12-08 09:58:32,Timestamp: 1638928712, Blocknumber: 13762078
# Decreased position： Position(L=0, tick=[190140, 195240], range=[3320.9204, 5530.1585])
# 【Decreased amount】: token0=616906.982662, token1=133.0860449158273
# Wallet amount: token0=617361.66005, token1=169.72145720431945
# 撤池后经转换 Wallet amount: token0=1314527.935294, token1=8.405485925232167
# **********************【Price Over MA】【创建Long Vol池子】【第18次建池】***********************************
# 转换后钱包中余额 amount0:  591176075701.0 amount1:  176412858310625871244
# price:  0.00023248595585929433
# $$$$$$$【Upper Price】: 0.0002997886683559921
# $$$$$$$【Lower Price】: 0.0001802927374413864
# ######【L】:75946413228040080【USDC】:591176075701【ETH】:139784095125617606656
# 将要投入池子的数量 amount_t0: 591176075700 amount_t1: 139784095125617475584
# 【RealWorldTime】:2021-12-08 11:53:39, Timestamp: 1638935619, Blocknumber: 13762575
# Mint position： Position(L=75938179374368720, tick=[190080, 195180], range=[3340.9048, 5563.4375])
# 【Mint amount】: token0=591046.796619, token1=139.78409512561748
# Wallet amount: token0=129.279082, token1=36.62876318500838
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00023115973555225164) out of range(0.0001802927374413864, 0.0002997886683559921)
# 【RealWorldTime】:2021-12-08 17:59:49,Timestamp: 1638957589, Blocknumber: 13764192
# Decreased position： Position(L=0, tick=[190080, 195180], range=[3340.9048, 5563.4375])
# 【Decreased amount】: token0=612403.314616, token1=134.84009320809886
# Wallet amount: token0=612532.593698, token1=171.46885639310725
# 撤池后经转换 Wallet amount: token0=1318891.88518, token1=8.49214212300633
# **********************【Price Over MA】【创建Long Vol池子】【第19次建池】***********************************
# 转换后钱包中余额 amount0:  593138653063.0 amount1:  177124376247772251300
# price:  0.00023250395620750538
# $$$$$$$【Upper Price】: 0.0002998118796523484
# $$$$$$$【Lower Price】: 0.00018030669670203025
# ######【L】:76198538977800352【USDC】:593138653063【ETH】:140248148242679037952
# 将要投入池子的数量 amount_t0: 593138653062 amount_t1: 140248148242678906880
# 【RealWorldTime】:2021-12-08 21:55:32, Timestamp: 1638971732, Blocknumber: 13765171
# Mint position： Position(L=76067972464248368, tick=[190080, 195180], range=[3340.9048, 5563.4375])
# 【Mint amount】: token0=591088.839226, token1=140.2481482426789
# Wallet amount: token0=2049.813837, token1=36.876228005093346
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False
# Price(0.00023066323537569648) out of range(0.00018030669670203025, 0.0002998118796523484)
# 【RealWorldTime】:2021-12-09 16:56:23,Timestamp: 1639040183, Blocknumber: 13770131
# Decreased position： Position(L=0, tick=[190080, 195180], range=[3340.9048, 5563.4375])
# 【Decreased amount】: token0=612687.136243, token1=135.2464427240313
# Wallet amount: token0=614736.95008, token1=172.12267072912465
# 撤池后经转换 Wallet amount: token0=1323745.052009, token1=8.525520455147088

# %% [markdown]
# # 获取原始绩效

# %%
positions = report.positions
positions
# Out:
# {1: <univ3api.simulation.PositionReport at 0x25989b84670>,
#  2: <univ3api.simulation.PositionReport at 0x259921873d0>,
#  3: <univ3api.simulation.PositionReport at 0x25992187bb0>,
#  4: <univ3api.simulation.PositionReport at 0x25992187f40>,
#  5: <univ3api.simulation.PositionReport at 0x259921178b0>,
#  6: <univ3api.simulation.PositionReport at 0x25992117df0>,
#  7: <univ3api.simulation.PositionReport at 0x2598a5f0550>,
#  8: <univ3api.simulation.PositionReport at 0x2598a5f09d0>,
#  9: <univ3api.simulation.PositionReport at 0x2598a5f0f70>,
#  10: <univ3api.simulation.PositionReport at 0x2598a60a6d0>,
#  11: <univ3api.simulation.PositionReport at 0x2598a60ad30>,
#  12: <univ3api.simulation.PositionReport at 0x2598a5ee550>,
#  13: <univ3api.simulation.PositionReport at 0x2598a5eea30>,
#  14: <univ3api.simulation.PositionReport at 0x2598a5eefd0>,
#  15: <univ3api.simulation.PositionReport at 0x25990680760>,
#  16: <univ3api.simulation.PositionReport at 0x25990680dc0>,
#  17: <univ3api.simulation.PositionReport at 0x259906935e0>,
#  18: <univ3api.simulation.PositionReport at 0x25990693ac0>,
#  19: <univ3api.simulation.PositionReport at 0x25990693fa0>}

# %%
positions[5].get_balance(plain=True, draw_plot=True)
# Out:
#                 datetime        amount0         fee0      cumFee0  \
# 0    2021-07-26 06:56:05  441765.867343     0.000000     0.000000
# 1    2021-07-26 07:03:40  442015.368765     0.124750     0.124750
# 2    2021-07-26 07:04:19  442452.758098     0.218694     0.343444
# 3    2021-07-26 07:04:38  443034.904519     0.291073     0.634517
# 4    2021-07-26 07:05:54  443286.236870     0.125666     0.760183
# ...                  ...            ...          ...          ...
# 7855 2021-08-05 22:38:48  944040.045190     0.949280  1755.006298
# 7856 2021-08-05 22:39:57  944800.244846     0.380099  1755.386397
# 7857 2021-08-05 22:40:08  948699.550029     1.949652  1757.336049
# <AxesSubplot:title={'center':'Total Balance'}>

# %%
eth_balance
eth_balance_df = pd.DataFrame(eth_balance)
eth_balance_df.columns = ['eth_balance']
eth_balance_df
# Out:
#              eth_balance
# timestamp
# 1620609472      0.000000
# 1620609830      0.000000
# 1620609889      0.000000
# 1620609894      0.000000
# 1620610623      0.000000
# ...                  ...
# 1639441611  32345.020306
# 1639441705  32418.365313
# 1639441911  32419.801867
# 1639441943  32477.193268
# 1639442093           NaN
#
# [132244 rows x 1 columns]

# %%
usdc_balance
usdc_balance_df = pd.DataFrame(usdc_balance)
usdc_balance_df.columns = ['usdc_balance']
usdc_balance_df
# Out:
#             usdc_balance
# timestamp
# 1620609472  1.000000e+06
# 1620609830  1.000000e+06
# 1620609889  1.000000e+06
# 1620609894  1.000000e+06
# 1620610623  1.000000e+06
# ...                  ...
# 1639441438  1.323745e+06
# 1639441611  1.323745e+06
# 1639441705  1.323745e+06
# 1639441911  1.323745e+06
# 1639441943  1.323745e+06
#
# [132243 rows x 1 columns]

# %%
tb_Timing
# Out:
# 2021-05-10 09:17:52    1.000000e+06
# 2021-05-10 09:23:50    1.000000e+06
# 2021-05-10 09:24:49    1.000000e+06
# 2021-05-10 09:24:54    1.000000e+06
# 2021-05-10 09:37:03    1.000000e+06
#                            ...
# 2021-12-14 08:26:51    1.356090e+06
# 2021-12-14 08:28:25    1.356163e+06
# 2021-12-14 08:31:51    1.356165e+06
# 2021-12-14 08:32:23    1.356222e+06
# 2021-12-14 08:34:53             NaN
# Length: 132244, dtype: float64

# %% [markdown]
# # 计算绩效指标

# %%
# tb_Timing.resample('D').sum()
pd.to_datetime(tb_Timing.index.tolist()[0])
tb_Timing.index = pd.to_datetime(tb_Timing.index)
tb_Timing.resample('D').last()
# Out:
# 2021-05-10    1.000000e+06
# 2021-05-11    1.000000e+06
# 2021-05-12    1.000000e+06
# 2021-05-13    1.000000e+06
# 2021-05-14    1.000000e+06
#                   ...
# 2021-12-10    1.357950e+06
# 2021-12-11    1.358240e+06
# 2021-12-12    1.358138e+06
# 2021-12-13    1.356145e+06
# 2021-12-14    1.356222e+06
# Freq: D, Length: 219, dtype: float64

# %%
df_tb = pd.DataFrame(tb_Timing.resample('D').last(),columns=['close'])
df_tb['return'] = df_tb['close'].pct_change()
df_tb['return_2'] = df_tb['close']/df_tb['close'].shift(1) - 1
df_tb = df_tb.iloc[:-1,:]
df_tb
# Out:
#                    close    return  return_2
# 2021-05-10  1.000000e+06       NaN       NaN
# 2021-05-11  1.000000e+06  0.000000  0.000000
# 2021-05-12  1.000000e+06  0.000000  0.000000
# 2021-05-13  1.000000e+06  0.000000  0.000000
# 2021-05-14  1.000000e+06  0.000000  0.000000
# ...                  ...       ...       ...
# 2021-12-09  1.359533e+06 -0.010529 -0.010529
# 2021-12-10  1.357950e+06 -0.001164 -0.001164
# 2021-12-11  1.358240e+06  0.000213  0.000213
# 2021-12-12  1.358138e+06 -0.000075 -0.000075
# 2021-12-13  1.356145e+06 -0.001468 -0.001468
#
# [218 rows x 3 columns]

# %%
df_tb['close'].plot()
# Out:
# <AxesSubplot:>

# %%
from scipy.stats.mstats import gmean
import math
def max_drawdown(df):
    """
    :return: Max drawdown of the financial series.
    """
    roll_max = df['close'].expanding().max()
    maxDrawdown = -1 * np.min(df['close'] / roll_max - 1)  # 计算得到最大回撤
    return maxDrawdown

def annual_return(df):
    """
    :return: Annual return.
    """
    annualReturn = gmean(df['return'].dropna() + 1) ** 365 - 1  # 得到年化收益率
    return annualReturn

def annual_std(df):
    """
    :return: The annual standard deviation.
    """
    dailyStd = df['return'].std()  # 得到日度波动率
    annualStd = dailyStd * math.sqrt(365)  # 得到年化波动率
    return annualStd

def sharpe_ratio(df):
    """
    :return:  Sharpe ratio.
    """
    annualReturn = annual_return(df)
    annualStd = annual_std(df)
    sharpeRatio = annualReturn / annualStd  # 得到夏普比
    return sharpeRatio

def calmar_ratio(df):
    """
    :return: Calmar ratio.
    """
    annualReturn = annual_return(df)
    maxDrawdown = max_drawdown(df)
    calmarRatio = annualReturn / maxDrawdown
    return calmarRatio

def max_drawdown_duration(df):
    """
    :return: Max Drawdown duration
    """
    xdate = df_tb.index.tolist()
    ycapital = df_tb['close'].tolist()
    duration = []
    tmp_max_capital = ycapital[0]
    for c in ycapital:
        if c >= tmp_max_capital:
            duration.append(0)
        else:
            duration.append(duration[-1]+1)
        tmp_max_capital = max(c, tmp_max_capital)
    MaxDDD = max(duration)
    endidx = np.argmax(duration)
    startidx = endidx - MaxDDD
#     print(xdate[startidx])
#     print(xdate[endidx])
    startD = xdate[startidx]
    endD = xdate[endidx]
#     return MaxDDD, startidx, endidx
    return MaxDDD, startD,endD

# %% [markdown]
# # 输出绩效

# %%
print('【SWAP_USDC_WETH_3000】')
print()

cumfee0 = backtest_report['cumFee0'].tolist()[-1]
cumfee1 = backtest_report['cumFee1'].tolist()[-1]/pricedata_res['price'].tolist()[-1]
print('USDC手续费',cumfee0,'ETH手续费(USDC计价)',cumfee1)
print('***************************资金曲线绩效***************************')
print('最大回撤',max_drawdown(df_tb))
print('最长回撤持续期',max_drawdown_duration(df_tb)[0],'日',
      '起始日期',max_drawdown_duration(df_tb)[1],
      '结束日期',max_drawdown_duration(df_tb)[2])
print('年化收益',annual_return(df_tb))
print('夏普比率',sharpe_ratio(df_tb))
print('卡尔玛比率',calmar_ratio(df_tb))
df_tb['close'].plot(title='Total Balance')
# Out:
# 【SWAP_USDC_WETH_3000】
#
# USDC手续费 12762.129382 ETH手续费(USDC计价) 13090.184595803546
# ***************************资金曲线绩效***************************
# 最大回撤 0.1121737208165886
# 最长回撤持续期 55 日 起始日期 2021-09-03 00:00:00 结束日期 2021-10-28 00:00:00
# 年化收益 0.6693310787566942
# 夏普比率 2.6122126334895386
# 卡尔玛比率 5.9669151908680504
# <AxesSubplot:title={'center':'Total Balance'}>

# %%
annualReturnNoneStrategy50 = 0.22855581332998387
annualReturnNoneStrategy100 = 0.29521239617921324
annualRetrunStrategy = 0.7828417999151238
print('相对Case_usdceth_none_3000_50per年化',annualRetrunStrategy - annualReturnNoneStrategy50)
print('相对Case_usdceth_none_3000_100per年化',annualRetrunStrategy - annualReturnNoneStrategy100)
# Out:
# 相对Case_usdceth_none_3000_50per年化 0.55428598658514
# 相对Case_usdceth_none_3000_100per年化 0.48762940373591057
