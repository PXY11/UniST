# %% [markdown]
# # 导入模块

# %%
import os
import sys

syspath = os.path.split(os.path.abspath("."))[0]
sys.path.append(syspath)

# %%
import univ3api.simulation as sim
import univ3api.utils as utils
import importlib
import pandas as pd

# %%
# run if simulation file is updated
importlib.reload(sim)
# Out:
# <module 'univ3api.simulation' from 'G:\\Python_proj\\Derivatives-China\\usdceth_strategy\\code\\univ3api\\simulation.py'>

# %% [markdown]
# ## 链上数据
#
# ### SwapEvent
#
# 记录了该流动性池的每一笔swap
#
# ### Block
#
# 区块信息，用于提供时间戳

# %%
HOST = "mongodb://172.16.11.81:27017/ETHDATA"
source = sim.DataUtilMongoDB(HOST)

# %% [markdown]
# # 转时间成Timestamp

# %%
from datetime import datetime
import time
d1 = datetime(2021,5, 10, 9)
d2 = datetime(2021,9, 1,9)
t1 = int(time.mktime(d1.timetuple()))
t2 = int(time.mktime(d2.timetuple()))

print(d1.timetuple())
print(time.mktime(d1.timetuple()))
print(int(time.mktime(d1.timetuple())))
print('**************************************************************************')
h=time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(t2))#再由中间格式转为字符串(str)
print(h)
print(time.localtime(t2))
# Out:
# time.struct_time(tm_year=2021, tm_mon=5, tm_mday=10, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=130, tm_isdst=-1)
# 1620608400.0
# 1620608400
# **************************************************************************
# 2021-09-01 09:00:00
# time.struct_time(tm_year=2021, tm_mon=9, tm_mday=1, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=244, tm_isdst=0)

# %%
swapdata = source.swap_by_time("SWAP_WETH_USDT_3000", t1, t2)

# %%
swapdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89859 entries, 0 to 89858
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transactionHash   89859 non-null  object
#  1   logIndex          89859 non-null  int64
#  2   transactionIndex  89859 non-null  int64
#  3   blockNumber       89859 non-null  int64
#  4   recipient         89859 non-null  object
#  5   amount0           89859 non-null  object
#  6   amount1           89859 non-null  int64
#  7   sqrtPriceX96      89859 non-null  object
#  8   liquidity         89859 non-null  object
#  9   tick              89859 non-null  int64
#  10  timestamp         89859 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 7.5+ MB

# %% [markdown]
# ### 先生成带时间戳的价格数据

# %%
swapdata.tail()
# Out:
#                                          transactionHash  logIndex  \
# 89854  0x6b236a1c63e56cf0fa11140df8e0066544a507ad64c3...        79
# 89855  0x0cd53e138d82fc204f6fd482d9fa8529b97d1d2e6527...        14
# 89856  0x1f40d32e3d8b481195f4f54f46e3ff9a6dc546c2cf77...        62
# 89857  0x6a6fe9781450b9e13bb2b9ab76d169e5a3ef1e0d92cb...        11
# 89858  0x15f56ed54c6e396a1898ce49008bb762a6aa5829afdb...         3
#
#        transactionIndex  blockNumber  \
# 89854                15     13136619
# 89855                 3     13136627
# 89856                 8     13136628
# 89857                 2     13136630
# 89858                 0     13136650
#
#                                         recipient                amount0  \
# 89854  0x56178a0d5F301bAf6CF3e1Cd53d9863437345Bf9  145814684683602982470
# 89855  0x56178a0d5F301bAf6CF3e1Cd53d9863437345Bf9  138778256571029358535
# 89856  0x30c5312d9CF0d873994f000e72F1cbf561D0209C    5905315769464742801
# 89857  0x56178a0d5F301bAf6CF3e1Cd53d9863437345Bf9  120371991767956761948
# 89858  0x56178a0d5F301bAf6CF3e1Cd53d9863437345Bf9   72937003999237118414
#
#             amount1               sqrtPriceX96             liquidity    tick  \
# 89854 -497167401705  4631662768854013417290124  12664890714804986397 -194954
# 89855 -472556781740  4628706580257992200781605  12664890714804986397 -194966
# 89856  -20094935817  4628580871724334153468064  12664890714804986397 -194967
# 89857 -409370738059  4626019958085682040554705  12664890714804986397 -194978
# 89858 -247829694775  4624469601925831472801006  12664890714804986397 -194985
#
#         timestamp
# 89854  1630457126
# 89855  1630457282
# 89856  1630457308
# 89857  1630457355
# 89858  1630457561

# %%
pricedata = swapdata[["timestamp", "sqrtPriceX96"]]
pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(18, 6).x96_to_price)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 2021-05-30  False
# 2021-05-31  False
# 2021-06-01  False
# 2021-06-02  False
# 2021-06-03  False
# 2021-06-04  False
# 2021-06-05  False
# 2021-06-06  False
# 2021-06-07  False
# 2021-06-08  False
# 2021-06-09  False
# 2021-06-10  False
# 2021-06-11  False
# 2021-06-12  False
# 2021-06-13  False
# 2021-06-14  False
# 2021-06-15  False
# 2021-06-16  False
# 2021-06-17  False
# 2021-06-18  False
# 2021-06-19  False
# 2021-06-20  False
# 2021-06-21  False
# 2021-06-22  False
# 2021-06-23  False
# 2021-06-24  False
# 2021-06-25  False
# 2021-06-26  False
# 2021-06-27  False
# 2021-06-28  False
# 2021-06-29  False
# 2021-06-30  False
# 2021-07-01  False
# 2021-07-02  False
# 2021-07-03  False
# 2021-07-04  False
# 2021-07-05  False
# 2021-07-06  False
# 2021-07-07  False
# 2021-07-08  False

# %%
priceDay.index = list(map(lambda d: d.date(), priceDay.index))
priceDay
# Out:
#              timestamp               sqrtPriceX96        price         MA50  \
# 2021-05-10  1620662393  5097148007396507342525763  4138.999001          NaN
# 2021-05-11  1620748786  5015438952242858931350730  4007.363421          NaN
# 2021-05-12  1620834998  5132057680743997015315634  4195.888031          NaN
# 2021-05-13  1620921557  4860429471490566366625907  3763.484430          NaN
# 2021-05-14  1621007802  5088923137812637218327691  4125.652219          NaN
# ...                ...                        ...          ...          ...
# 2021-08-28  1630166226  4505558867136721069779417  3233.986251  2636.802681
# 2021-08-29  1630249684  4468081520634073078437323  3180.409258  2658.036747
# 2021-08-30  1630339014  4493852604629865024951440  3217.203111  2679.554154
# 2021-08-31  1630425102  4606504872862707540341485  3380.523056  2705.320662
# 2021-09-01  1630457561  4624469601925831472801006  3406.941611  2733.469265
#
#             Trend
# 2021-05-10  False
# 2021-05-11  False
# 2021-05-12  False
# 2021-05-13  False
# 2021-05-14  False
# ...           ...
# 2021-08-28   True
# 2021-08-29   True
# 2021-08-30   True
# 2021-08-31   True
# 2021-09-01   True
#
# [115 rows x 5 columns]

# %%
trendDict = dict(priceDay['Trend'])
trendDict
# Out:
# {datetime.date(2021, 5, 10): False,
#  datetime.date(2021, 5, 11): False,
#  datetime.date(2021, 5, 12): False,
#  datetime.date(2021, 5, 13): False,
#  datetime.date(2021, 5, 14): False,
#  datetime.date(2021, 5, 15): False,
#  datetime.date(2021, 5, 16): False,
#  datetime.date(2021, 5, 17): False,
#  datetime.date(2021, 5, 18): False,
#  datetime.date(2021, 5, 19): False,
#  datetime.date(2021, 5, 20): False,
#  datetime.date(2021, 5, 21): False,
#  datetime.date(2021, 5, 22): False,
#  datetime.date(2021, 5, 23): False,
#  datetime.date(2021, 5, 24): False,
#  datetime.date(2021, 5, 25): False,
#  datetime.date(2021, 5, 26): False,
#  datetime.date(2021, 5, 27): False,
#  datetime.date(2021, 5, 28): False,
#  datetime.date(2021, 5, 29): False,
#  datetime.date(2021, 5, 30): False,
#  datetime.date(2021, 5, 31): False,
#  datetime.date(2021, 6, 1): False,
#  datetime.date(2021, 6, 2): False,
#  datetime.date(2021, 6, 3): False,
#  datetime.date(2021, 6, 4): False,
#  datetime.date(2021, 6, 5): False,
#  datetime.date(2021, 6, 6): False,
#  datetime.date(2021, 6, 7): False,
#  datetime.date(2021, 6, 8): False,
#  datetime.date(2021, 6, 9): False,
#  datetime.date(2021, 6, 10): False,
#  datetime.date(2021, 6, 11): False,
#  datetime.date(2021, 6, 12): False,
#  datetime.date(2021, 6, 13): False,
#  datetime.date(2021, 6, 14): False,
#  datetime.date(2021, 6, 15): False,
#  datetime.date(2021, 6, 16): False,
#  datetime.date(2021, 6, 17): False,
#  datetime.date(2021, 6, 18): False,
#  datetime.date(2021, 6, 19): False,
#  datetime.date(2021, 6, 20): False,
#  datetime.date(2021, 6, 21): False,
#  datetime.date(2021, 6, 22): False,
#  datetime.date(2021, 6, 23): False,
#  datetime.date(2021, 6, 24): False,
#  datetime.date(2021, 6, 25): False,
#  datetime.date(2021, 6, 26): False,
#  datetime.date(2021, 6, 27): False,
#  datetime.date(2021, 6, 28): False,
#  datetime.date(2021, 6, 29): False,
#  datetime.date(2021, 6, 30): False,
#  datetime.date(2021, 7, 1): False,
#  datetime.date(2021, 7, 2): False,
#  datetime.date(2021, 7, 3): False,
#  datetime.date(2021, 7, 4): False,
#  datetime.date(2021, 7, 5): False,
#  datetime.date(2021, 7, 6): False,
#  datetime.date(2021, 7, 7): False,
#  datetime.date(2021, 7, 8): False,
#  datetime.date(2021, 7, 9): False,
#  datetime.date(2021, 7, 10): False,
#  datetime.date(2021, 7, 11): False,
#  datetime.date(2021, 7, 12): False,
#  datetime.date(2021, 7, 13): False,
#  datetime.date(2021, 7, 14): False,
#  datetime.date(2021, 7, 15): False,
#  datetime.date(2021, 7, 16): False,
#  datetime.date(2021, 7, 17): False,
#  datetime.date(2021, 7, 18): False,
#  datetime.date(2021, 7, 19): False,
#  datetime.date(2021, 7, 20): False,
#  datetime.date(2021, 7, 21): False,
#  datetime.date(2021, 7, 22): False,
#  datetime.date(2021, 7, 23): False,
#  datetime.date(2021, 7, 24): False,
#  datetime.date(2021, 7, 25): False,
#  datetime.date(2021, 7, 26): True,
#  datetime.date(2021, 7, 27): True,
#  datetime.date(2021, 7, 28): True,
#  datetime.date(2021, 7, 29): True,
#  datetime.date(2021, 7, 30): True,
#  datetime.date(2021, 7, 31): True,
#  datetime.date(2021, 8, 1): True,
#  datetime.date(2021, 8, 2): True,
#  datetime.date(2021, 8, 3): True,
#  datetime.date(2021, 8, 4): True,
#  datetime.date(2021, 8, 5): True,
#  datetime.date(2021, 8, 6): True,
#  datetime.date(2021, 8, 7): True,
#  datetime.date(2021, 8, 8): True,
#  datetime.date(2021, 8, 9): True,
#  datetime.date(2021, 8, 10): True,
#  datetime.date(2021, 8, 11): True,
#  datetime.date(2021, 8, 12): True,
#  datetime.date(2021, 8, 13): True,
#  datetime.date(2021, 8, 14): True,
#  datetime.date(2021, 8, 15): True,
#  datetime.date(2021, 8, 16): True,
#  datetime.date(2021, 8, 17): True,
#  datetime.date(2021, 8, 18): True,
#  datetime.date(2021, 8, 19): True,
#  datetime.date(2021, 8, 20): True,
#  datetime.date(2021, 8, 21): True,
#  datetime.date(2021, 8, 22): True,
#  datetime.date(2021, 8, 23): True,
#  datetime.date(2021, 8, 24): True,
#  datetime.date(2021, 8, 25): True,
#  datetime.date(2021, 8, 26): True,
#  datetime.date(2021, 8, 27): True,
#  datetime.date(2021, 8, 28): True,
#  datetime.date(2021, 8, 29): True,
#  datetime.date(2021, 8, 30): True,
#  datetime.date(2021, 8, 31): True,
#  datetime.date(2021, 9, 1): True}

# %%
priceDt['date'] = list(map(lambda d: d.date(), priceDt.index))

# %%
priceDt
# Out:
#                       timestamp               sqrtPriceX96        price  \
# datetime
# 2021-05-10 09:00:15  1620608415  4950372593694415524150419  3904.061118
# 2021-05-10 09:03:40  1620608620  4950714025650391927763989  3904.599670
# 2021-05-10 09:05:17  1620608717  4950722657183851518816584  3904.613285
# 2021-05-10 09:19:10  1620609550  4949701065479238300877944  3903.002002
# 2021-05-10 09:21:38  1620609698  4949886229297224528026940  3903.294023
# ...                         ...                        ...          ...
# 2021-09-01 08:45:26  1630457126  4631662768854013417290124  3417.548561
# 2021-09-01 08:48:02  1630457282  4628706580257992200781605  3413.187409
# 2021-09-01 08:48:28  1630457308  4628580871724334153468064  3413.002017
# 2021-09-01 08:49:15  1630457355  4626019958085682040554705  3409.226352
# 2021-09-01 08:52:41  1630457561  4624469601925831472801006  3406.941611
#
#                            date
# datetime
# 2021-05-10 09:00:15  2021-05-10
# 2021-05-10 09:03:40  2021-05-10
# 2021-05-10 09:05:17  2021-05-10
# 2021-05-10 09:19:10  2021-05-10
# 2021-05-10 09:21:38  2021-05-10
# ...                         ...
# 2021-09-01 08:45:26  2021-09-01
# 2021-09-01 08:48:02  2021-09-01
# 2021-09-01 08:48:28  2021-09-01
# 2021-09-01 08:49:15  2021-09-01
# 2021-09-01 08:52:41  2021-09-01
#
# [89859 rows x 4 columns]

# %%
trendList = []
for i, v in priceDt.iterrows():
    trendList.append(trendDict[v['date']])
print('len of trendList:{}'.format(len(trendList)))
# Out:
# len of trendList:89859

# %%
priceDt['trend'] = trendList

# %%
priceDt.tail()
# Out:
#                       timestamp               sqrtPriceX96        price  \
# datetime
# 2021-09-01 08:45:26  1630457126  4631662768854013417290124  3417.548561
# 2021-09-01 08:48:02  1630457282  4628706580257992200781605  3413.187409
# 2021-09-01 08:48:28  1630457308  4628580871724334153468064  3413.002017
# 2021-09-01 08:49:15  1630457355  4626019958085682040554705  3409.226352
# 2021-09-01 08:52:41  1630457561  4624469601925831472801006  3406.941611
#
#                            date  trend
# datetime
# 2021-09-01 08:45:26  2021-09-01   True
# 2021-09-01 08:48:02  2021-09-01   True
# 2021-09-01 08:48:28  2021-09-01   True
# 2021-09-01 08:49:15  2021-09-01   True
# 2021-09-01 08:52:41  2021-09-01   True

# %% [markdown]
# ### 初始化参数

# %%
init_price = priceDt["price"][0]

decimal0 = 18
decimal1 = 6

init_amount0 = 0
init_amount1 = 1000000*1e6

# %% [markdown]
# ### 运行策略

# %% [markdown]
# ```
# token0 表示eth
# token1 表示usdt
# ```

# %%
import ethusdt_strategy
importlib.reload(utils)
importlib.reload(sim)
importlib.reload(ethusdt_strategy)
print('token0 表示eth   token1 表示usdt')
strategy = ethusdt_strategy.HoldStrategy(init_amount0, init_amount1, decimal0, decimal1, sim.PoolFee.low, False)
strategy.init(swapdata.iloc[0].to_dict())
strategy.run(swapdata, priceDt)
report = strategy.report()
# Out:
# token0 表示eth   token1 表示usdt
# C:\Users\mojunjie\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py:1490: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   FutureWarning,
# ***************************************************【创建池子】***************************************************
# $$$$$$$【Upper Price】: 2670.057793611629
# $$$$$$$【Lower Price】: 1708.8369879114427
# ######: 101756322027883072 228638780244870037504 499750000000
# ######【L】:101756322027883072【ETH】:228638780244870037504【USD】:499750000000
# amount_t0: 228638780244870266880 amount_t1: 499750000000
# Timestamp : 1627228257, Blocknumber : 12896322
# Mint position： Position(L=101370775942769696, tick=[-201900, -197460], range=[1706.2113, 2659.8057])
# Mint amount: token0=226.8863962841141, token1=499750.0
# Wallet amount: token0=6.977599094808281, token1=0.0
# ***************************************************【撤销池子】***************************************************
# Price(2672.479561316052) out of range(1708.8369879114427, 2670.057793611629)
# 1627848347, 12941671
# Decreased position： Position(L=0, tick=[-201900, -197460], range=[1706.2113, 2659.8057])
# Decreased amount: token0=0.0, token1=1040773.146157
# Wallet amount: token0=6.977599094808281, token1=1040773.146157
# ***************************************************【创建池子】***************************************************
# $$$$$$$【Upper Price】: 3345.2186488996817
# $$$$$$$【Lower Price】: 2140.9399352957967
# ######: 93364043660190848 189435063876001431552 520804894709
# ######【L】:93364043660190848【ETH】:189435063876001431552【USD】:520804894709
# amount_t0: 189435063876001431552 amount_t1: 520804894709
# Timestamp : 1627848487, Blocknumber : 12941682
# Mint position： Position(L=92725112177527712, tick=[-199680, -195180], range=[2130.3029, 3340.9048])
# Mint amount: token0=189.43506387600132, token1=513773.719943
# Wallet amount: token0=12.576406534748932, token1=7031.174766
# ***************************************************【撤销池子】***************************************************
# Price(3346.5955668625297) out of range(2140.9399352957967, 3345.2186488996817)
# 1629713019, 13080905
# Decreased position： Position(L=0, tick=[-199680, -195180], range=[2130.3029, 3340.9048])
# Decreased amount: token0=0.0, token1=1079816.970084
# Wallet amount: token0=12.576406534748932, token1=1086848.14485
# ***************************************************【创建池子】***************************************************
# $$$$$$$【Upper Price】: 4183.355851082022
# $$$$$$$【Lower Price】: 2677.347744692494
# ######: 88987883017020320 160356356140193382400 544993249268
# ######【L】:88987883017020320【ETH】:160356356140193382400【USD】:544993249268
# amount_t0: 160356356140193185792 amount_t1: 544993249267
# Timestamp : 1629713022, Blocknumber : 13080906
# Mint position： Position(L=88946074774170160, tick=[-197400, -192960], range=[2675.8117, 4171.3118])
# Mint amount: token0=160.35635614019304, token1=544485.060821
# Wallet amount: token0=16.169232732619385, token1=508.188447

# %% [markdown]
# ### 池子在回测时间内发生了3次建池，2次撤池

# %% [markdown]
# ### 画图 查看每次建池的资产状况

# %%
report.positions[1].get_balance(plain=True, draw_plot=True)
# Out:
#                 datet
get_balance(plain=True, draw_plot=True)
# Out:
#                 datetime  amount0      fee0   cumFee0  collectedFee0  \
# 0    2021-08-23 18:03:42  160.356  0.000000  0.000000       0.000000
# 1    2021-08-23 18:03:54  160.336  0.000000  0.000000       0.000000
# 2    2021-08-23 18:05:07  160.013  0.000000  0.000000       0.000000
# 3    2021-08-23 18:05:27  159.561  0.000000  0.000000       0.000000
# 4    2021-08-23 18:06:09  159.557  0.000000  0.000000       0.000000
# ...                  ...      ...       ...       ...            ...
# 2670 2021-09-01 08:42:54  143.291  0.000415  0.263985       0.263985
# 2671 2021-09-01 08:45:26  144.312  0.000510  0.264496       0.264496
# 2672 2021-09-01 08:48:02  145.284  0.000486  0.264982       0.264982
# 2673 2021-09-01 08:48:28  145.325  0.000021  0.265002       0.265002
# 2674 2021-09-01 08:49:15  146.168  0.000421  0.265424       0.265424
#
#             amount1      fee1     cumFee1  collectedFee1
# 0     544485.060821  0.000000    0.000000       0.000000
# 1     544553.568340  0.034253    0.034253       0.034253
# 2     545635.525052  0.540978    0.575231       0.575231
# 3     547147.198077  0.755836    1.331067       1.331067
# 4     547163.202069  0.008001    1.339068       1.339068
# ...             ...       ...         ...            ...
# 2670  602236.940020  0.000000  882.000803     882.000803
# 2671  598745.345097  0.000000  882.000803     882.000803
# 2672  595426.558399  0.000000  882.000803     882.000803
# 2673  595285.430796  0.000000  882.000803     882.000803
# 2674  592410.402413  0.000000  882.000803     882.000803
#
# [2675 rows x 9 columns]

# %% [markdown]
# ### 展示总体资产状况
#
# ```
# TotalAmount = WalletAmount + AmountInPositions + CummulativeFee
# ```

# %%
total_balance = report.total_balance(draw_plot=True, plain=True)

# %%
price = pricedata.drop_duplicates("timestamp").set_index("timestamp")["price"]
price
# Out:
# timestamp
# 1620608415    3904.061118
# 1620608620    3904.599670
# 1620608717    3904.613285
# 1620609550    3903.002002
# 1620609698    3903.294023
#                  ...
# 1630457126    3417.548561
# 1630457282    3413.187409
# 1630457308    3413.002017
# 1630457355    3409.226352
# 1630457561    3406.941611
# Name: price, Length: 72807, dtype: float64

# %%
eth_balance = total_balance.set_index("timestamp")[["amount0", "cumFee0"]].sum(axis=1) * price

# %%
usdt_balance = total_balance.set_index("timestamp")[["amount1", "cumFee1"]].sum(axis=1)

# %%
usdt_balance+eth_balance
# Out:
# timestamp
# 1620608415    1.000000e+06
# 1620608620    1.000000e+06
# 1620608717    1.000000e+06
# 1620609550    1.000000e+06
# 1620609698    1.000000e+06
#                   ...
# 1630457126    1.159184e+06
# 1630457282    1.158478e+06
# 1630457308    1.158448e+06
# 1630457355    1.157833e+06
# 1630457561             NaN
# Length: 72807, dtype: float64

# %%
# eth_balance.plot()
# usdt_balance.plot()
tb_Timing = (usdt_balance+eth_balance)

# %%
tb_Timing.plot()

# %% [markdown]
# ### 账户总体市值和价格变动

# %%
assets_value = pricedata.set_index("timestamp")["price"] * (total_balance["amount1"] / 10**decimal1) + total_balance["amount0"] / 10**decimal0
assets_value.plot()
pricedata.set_index("timestamp")[["price"]].plot()
