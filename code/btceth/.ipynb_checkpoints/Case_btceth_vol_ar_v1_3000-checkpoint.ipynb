# %% [markdown]
# # 获取原始数据

# %%
import os
import sys
import talib as ta
syspath = os.path.split(os.path.abspath("."))[0]
sys.path.append(syspath)
import univ3api.simulation as sim
import univ3api.utils as utils
import importlib
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import pickle
import talib as ta
from dateutil.parser import parse
import numpy as np
# run if simulation file is updated
importlib.reload(sim)

HOST = "mongodb://172.16.20.81:27017/ETHDATA"
source = sim.DataUtilMongoDB(HOST)

from datetime import datetime
import time
d1 = datetime(2021,5,10, 9)
d2 = datetime(2021,11,10,9)
t1 = int(time.mktime(d1.timetuple()))
t2 = int(time.mktime(d2.timetuple()))

# print(d1.timetuple())
# print(time.mktime(d1.timetuple()))
# print(int(time.mktime(d1.timetuple())))

# swapdata = source.swap_by_time("SWAP_WETH_USDT_3000", t1, t2)
swapdata = source.swap_by_time("SWAP_WBTC_WETH_3000", t1, t2)
swapdata.tail()
pricedata = swapdata[["timestamp", "sqrtPriceX96"]]
# pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(18, 6).x96_to_price)
pricedata["price"] = pricedata["sqrtPriceX96"].apply(utils.PriceConverter(8, 18).x96_to_price)
pricedata['datetime']  = pd.to_datetime(pricedata['timestamp'],unit='s')
pricedata['datetime'] = [str(tmp)[:] for tmp in pricedata['datetime'].tolist()]
pricedata
# Out:
#         timestamp                         sqrtPriceX96      price  \
# 0      1620608457  30685129890900272086470739815588235  15.000190
# 1      1620608457  30709533659969384051347723595723166  15.024059
# 2      1620608592  30705863068469425277565093729731105  15.020468
# 3      1620608683  30724919029063427727612188810824282  15.039117
# 4      1620608715  30722150531496348621299112840911173  15.036406
# ...           ...                                  ...        ...
# 48906  1636503509  29774922511961089343557287689272623  14.123493
# 48907  1636503788  29777538572175576629925813454628677  14.125975
# 48908  1636503867  29779112171410890340359447285519816  14.127468
# 48909  1636503933  29785324667474397808596827643830253  14.133363
# 48910  1636505218  29785375555905204108892719062995588  14.133411
#
#                   datetime
# 0      2021-05-10 01:00:57
# 1      2021-05-10 01:00:57
# 2      2021-05-10 01:03:12
# 3      2021-05-10 01:04:43
# 4      2021-05-10 01:05:15
# ...                    ...
# 48906  2021-11-10 00:18:29
# 48907  2021-11-10 00:23:08
# 48908  2021-11-10 00:24:27
# 48909  2021-11-10 00:25:33
# 48910  2021-11-10 00:46:58
#
# [48911 rows x 4 columns]

# %%
pricedata['datetime'].tolist()[0]
# Out:
# '2021-05-10 01:00:57'

# %%
pricedata_plot = pricedata.copy(deep=True)
pricedata_plot = pricedata_plot[pricedata_plot['datetime']<'2021-05-13 00:00:00']
pricedata_plot = pricedata_plot[pricedata_plot['datetime']>'2021-05-12 00:00:00']
pricedata_plot = pricedata_plot[pricedata_plot['datetime']>'2021-05-12 00:00:00']
pricedata_plot.set_index('datetime')['price'].plot(rot = 60,grid=True)
# pricedata_plot.set_index('datetime')['price'].plot(rot = 60)
# pricedata_plot[pricedata_plot['datetime']<'2021-05-15 00:00:00'].set_index('datetime')['price'].plot(rot = 60)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# # 指标计算arRollNorm

# %%
import pickle
from scipy import stats
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
symbolSigDataAR = load_obj('ARdata/symbolsSigAvg_2018050120211124_60min_v18_ar')['60min']

# AR Rolling Normalization ####################################################
def normalizationProcess(dataArray):
    q75 = np.quantile(dataArray, 0.75)
    q50 = np.quantile(dataArray, 0.5)
    q25 = np.quantile(dataArray, 0.25)
    scaleResult = 100*stats.norm.cdf(0.5*(dataArray[-1]-q50)/(q75-q25))-50
    return scaleResult

def get_ar_norm(df,arCol,WinSize):
    arRollNorm = df[arCol].dropna().rolling(WinSize).apply(normalizationProcess)
    return arRollNorm

ar_param = 144
winsize = 288
symbolSigDataAR[f'arRollNorm{winsize}'] = get_ar_norm(symbolSigDataAR,f'ar{ar_param}',winsize)

startInd = f'{d1.year}-{d1.month}-{d1.day}'
symbolSigDataARRollNorm = symbolSigDataAR.loc[startInd:]
symbolSigDataARRollNormSub = symbolSigDataARRollNorm.reset_index()[[('timestamp',''),(f'arRollNorm{winsize}','')]]
symbolSigDataARRollNormSub.columns = ['datetime',f'arRollNorm{winsize}']
symbolSigDataARRollNormSub['price'] = [np.nan]*len(symbolSigDataARRollNormSub)
symbolSigDataARRollNormSub['sqrtPriceX96'] = [np.nan]*len(symbolSigDataARRollNormSub)
symbolSigDataARRollNormSub['timestamp'] = [np.nan]*len(symbolSigDataARRollNormSub)
symbolSigDataARRollNormSub = symbolSigDataARRollNormSub[['timestamp','sqrtPriceX96','price','datetime',f'arRollNorm{winsize}']]
symbolSigDataARRollNormSub.index = [i for i in range(len(pricedata),len(pricedata)+len(symbolSigDataARRollNormSub))]
symbolSigDataARRollNormSub

pricedataExtend = pricedata.copy(deep=True)
pricedataExtend[f'arRollNorm{winsize}'] = [np.nan]*len(pricedataExtend)
pricedataExtend

datetimeTmp = symbolSigDataARRollNormSub['datetime'].tolist()
datetimeNew = [str(dt)[:-6] for dt in datetimeTmp]
symbolSigDataARRollNormSub['datetime'] = datetimeNew
bar = pricedataExtend.append(symbolSigDataARRollNormSub)

bar = bar.sort_values(by='datetime')
# bar.fillna(method='ffill')
bar = bar.fillna(method='ffill')
pricedata_res_arRollNorm = bar.loc[pricedataExtend.index]
pricedata_res_arRollNorm.set_index('datetime',inplace=True)
pricedata_res_arRollNorm = pricedata_res_arRollNorm[[f'arRollNorm{winsize}']]
pricedata_res_arRollNorm

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
#之后要扩展回测区间时，需要更新此处的基本行情数据
df_eth = load_obj('../../data/usdceth/symbolsData_2018032120211116_60min_v16_E')['60min']
df_eth.columns= ['open','high','low','close','volume']
df_eth = df_eth.loc['2018-03-22':'2021-11-09']
df_eth.reset_index(inplace=True)
df_eth.columns = ['datetime','open','high','low','close','volume']
def cal_indicator(dataCoin):    
    dataCoin['pctChange'] = dataCoin['close'].pct_change()
    dataCoin['pctStd'] = ta.STDDEV(dataCoin['pctChange'], 24*5)*(24**0.5)
    dataCoin['pctStdVma'] = ta.SUM(dataCoin['pctStd']*dataCoin['volume'], 24*50) / ta.SUM(dataCoin['volume'], 24*50)
    dataCoin['closeVma'] = ta.SUM(dataCoin['close']*dataCoin['volume'], 24*50) / ta.SUM(dataCoin['volume'], 24*50)
    dataCoin['pctStdVSma'] = ta.EMA(dataCoin.pctStdVma, 24*3)
    dataCoin['pctStdVLma'] = ta.MA(dataCoin.pctStdVma, 24*10)
    dataCoin['SmaLowerLma'] = dataCoin['pctStdVSma']<dataCoin['pctStdVLma']
    dataCoin['CloseLowerMA'] = dataCoin['close'] < dataCoin['closeVma']
    #根据volResearch notebook里的BelowMA的vol stat中quantile50的2018.5至2021.5波动率统计得出
    dataCoin['VolLowerBelowmaQuantile50'] = dataCoin['pctStd'] < 0.035857 
    #根据volResearch notebook里的OverMA的vol stat中quantile50的2018.5至2021.5波动率统计得出
    dataCoin['VolHigherOvermaQuantile50Twosigma'] = dataCoin['pctStd'] > (0.038511 + 2*0.018451)
    #当波动率高于Belowma的vol stat中的Quantile50的1.05倍时撤销池子
    dataCoin['revoke_pos'] = dataCoin['pctStd'] > 0.035857 *1.05
    
cal_indicator(df_eth)

df_eth_test_period = df_eth[df_eth['datetime']>parse('2021-05-10 00:00:00+00:00')]
df_signal_tmp = df_eth_test_period[['datetime',
                               'SmaLowerLma',
                               'VolLowerBelowmaQuantile50',
                               'CloseLowerMA',
                               'VolHigherOvermaQuantile50Twosigma',
                               'revoke_pos']]
df_signal_tmp['timestamp'] = [0]*len(df_signal_tmp)
df_signal_tmp['sqrtPriceX96'] = [0]*len(df_signal_tmp)
df_signal_tmp['price'] = [0]*len(df_signal_tmp)

df_signal_tmp = df_signal_tmp[['timestamp','sqrtPriceX96','price','datetime',
                 'SmaLowerLma',
                 'VolLowerBelowmaQuantile50',
                 'CloseLowerMA',
                 'VolHigherOvermaQuantile50Twosigma',
                 'revoke_pos']]
df_signal_tmp['datetime_2'] = df_signal_tmp['datetime']
df_signal_tmp = df_signal_tmp.set_index('datetime_2')
# df_signal_tmp = df_signal_tmp.resample('D').first()
df_signal_tmp['datetime'] = [str(tmp)[:-6] for tmp in df_signal_tmp['datetime'].tolist()]
df_signal_tmp['ind'] = [i for i in range(len(pricedata),len(pricedata)+len(df_signal_tmp))]
df_signal_tmp.set_index('ind',inplace=True)
pricedata_tmp = pricedata.append(df_signal_tmp)
pricedata_tmp = pricedata_tmp.sort_values(by='datetime')
pricedata_tmp_beforefill = pricedata_tmp.copy(deep = True)
pricedata_tmp = pricedata_tmp.fillna(method = 'ffill')
pricedata_res = pricedata_tmp.loc[pricedata.index]
pricedata_res.set_index('datetime',inplace=True)

pricedata_res[f'arRollNorm'] = pricedata_res_arRollNorm[f'arRollNorm{winsize}']
pricedata_res
# Out:
#                       timestamp                         sqrtPriceX96  \
# datetime
# 2021-05-10 01:00:57  1620608457  30685129890900272086470739815588235
# 2021-05-10 01:00:57  1620608457  30709533659969384051347723595723166
# 2021-05-10 01:03:12  1620608592  30705863068469425277565093729731105
# 2021-05-10 01:04:43  1620608683  30724919029063427727612188810824282
# 2021-05-10 01:05:15  1620608715  30722150531496348621299112840911173
# ...                         ...                                  ...
# 2021-11-10 00:18:29  1636503509  29774922511961089343557287689272623
# 2021-11-10 00:23:08  1636503788  29777538572175576629925813454628677
# 2021-11-10 00:24:27  1636503867  29779112171410890340359447285519816
# 2021-11-10 00:25:33  1636503933  29785324667474397808596827643830253
# 2021-11-10 00:46:58  1636505218  29785375555905204108892719062995588
#
#                          price  SmaLowerLma  VolLowerBelowmaQuantile50  \
# datetime
# 2021-05-10 01:00:57  15.000190        False                      False
# 2021-05-10 01:00:57  15.024059        False                      False
# 2021-05-10 01:03:12  15.020468        False                      False
# 2021-05-10 01:04:43  15.039117        False                      False
# 2021-05-10 01:05:15  15.036406        False                      False
# ...                        ...          ...                        ...
# 2021-11-10 00:18:29  14.123493         True                       True
# 2021-11-10 00:23:08  14.125975         True                       True
# 2021-11-10 00:24:27  14.127468         True                       True
# 2021-11-10 00:25:33  14.133363         True                       True
# 2021-11-10 00:46:58  14.133411         True                       True
#
#                      CloseLowerMA  VolHigherOvermaQuantile50Twosigma  \
# datetime
# 2021-05-10 01:00:57         False                              False
# 2021-05-10 01:00:57         False                              False
# 2021-05-10 01:03:12         False                              False
# 2021-05-10 01:04:43         False                              False
# 2021-05-10 01:05:15         False                              False
# ...                           ...                                ...
# 2021-11-10 00:18:29         False                              False
# 2021-11-10 00:23:08         False                              False
# 2021-11-10 00:24:27         False                              False
# 2021-11-10 00:25:33         False                              False
# 2021-11-10 00:46:58         False                              False
#
#                      revoke_pos  arRollNorm
# datetime
# 2021-05-10 01:00:57        True  -15.211088
# 2021-05-10 01:00:57        True  -15.211088
# 2021-05-10 01:03:12        True  -15.211088
# 2021-05-10 01:04:43        True  -15.211088
# 2021-05-10 01:05:15        True  -15.211088
# ...                         ...         ...
# 2021-11-10 00:18:29       False  -43.820580
# 2021-11-10 00:23:08       False  -43.820580
# 2021-11-10 00:24:27       False  -43.820580
# 2021-11-10 00:25:33       False  -43.820580
# 2021-11-10 00:46:58       False  -43.820580
#
# [48911 rows x 9 columns]

# %% [markdown]
# # 回测

# %%
init_price = pricedata_res["price"][0]

decimal0 = 8 #BTC的精度
decimal1 = 18 #ETH的精度

init_amount0 = 1000000*1e6 #初始持有BTC的数量
init_amount1 = 0 #初始持有ETH的数量
print('init_price =',init_price)
# Out:
# init_price = 15.000190153257385

# %% [markdown]
# # 建池撤池详细信息

# %%
import Strategy_btceth_vol_ar_v1
importlib.reload(utils)
importlib.reload(sim)
importlib.reload(Strategy_btceth_vol_ar_v1)
strategy = Strategy_btceth_vol_ar_v1.HoldStrategy(init_amount0, init_amount1, decimal0, decimal1, sim.PoolFee.low, True)
strategy.init(swapdata.iloc[0].to_dict())

# strategy.run(swapdata, priceDt)
strategy.run(swapdata, pricedata_res)

report = strategy.report()
# Out:
# **********************【Price Over MA】【创建Long Vol池子】【第1次建池】***********************************
# 转换后钱包中余额 amount0:  449725000000.0 amount1:  62649286404474811711488
# price:  13.747580536205303
# $$$$$$$【Upper Price】: 17.727388507545324
# $$$$$$$【Lower Price】: 10.661241531374369
# ######【L】:1397595515309502464【USDC】:449725000000【ETH】:62230877145216164298752
# 将要投入池子的数量 amount_t0: 449725000000 amount_t1: 62230877145216164298752
# 【RealWorldTime】:2021-06-04 06:52:40, Timestamp: 1622760760, Blocknumber: 12564328
# Mint position： Position(L=1397030982737295104, tick=[253920, 259020], range=[0.0564, 0.0940])
# 【Mint amount】: token0=4493.60486588, token1=62230.87714521617
# Wallet amount: token0=3.64513412, token1=418.4092592586474
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False,arRollNorm:-5.3800103061215125
# Price(13.731235286903543) out of range(10.661241531374369, 17.727388507545324)
# 【RealWorldTime】:2021-06-04 07:50:58,Timestamp: 1622764258, Blocknumber: 12564565
# Decreased position： Position(L=0, tick=[253920, 259020], range=[0.0564, 0.0940])
# 【Decreased amount】: token0=4516.13547672, token1=61921.32056302199
# Wallet amount: token0=4519.78061084, token1=62339.729822280635
# 撤池后经转换 Wallet amount: token0=8233.8146466, token1=3087.3751194484576
# **********************【Price Over MA】【创建Long Vol池子】【第2次建池】***********************************
# 转换后钱包中余额 amount0:  370295229195.0 amount1:  61098321985955505897472
# price:  15.684046177728629
# $$$$$$$【Upper Price】: 20.22444452903145
# $$$$$$$【Lower Price】: 12.162969625791963
# ######【L】:1228232878465694720【USDC】:370295229195【ETH】:58372112571355507982336
# 将要投入池子的数量 amount_t0: 370295229195 amount_t1: 58372112571355507982336
# 【RealWorldTime】:2021-07-24 23:59:45, Timestamp: 1627142385, Blocknumber: 12889966
# Mint position： Position(L=1225661524412604928, tick=[255240, 260340], range=[0.0494, 0.0823])
# 【Mint amount】: token0=3702.95229195, token1=58128.36181890941
# Wallet amount: token0=0.0, token1=2969.96016704609
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False,arRollNorm:6.231484892440733
# Price(15.712116992129545) out of range(12.162969625791963, 20.22444452903145)
# 【RealWorldTime】:2021-07-25 01:52:32,Timestamp: 1627149152, Blocknumber: 12890465
# Decreased position： Position(L=0, tick=[255240, 260340], range=[0.0494, 0.0823])
# 【Decreased amount】: token0=3668.02777968, token1=58676.417555773696
# Wallet amount: token0=3668.02777968, token1=61646.37772281979
# 撤池后经转换 Wallet amount: token0=6816.2941982, token1=3053.1991425479646
# **********************【Price Over MA】【创建Long Vol池子】【第3次建池】***********************************
# 转换后钱包中余额 amount0:  306545790829.0 amount1:  51918971603124621154504
# price:  15.96658513527316
# $$$$$$$【Upper Price】: 20.588776118558645
# $$$$$$$【Lower Price】: 12.38207843991908
# ######【L】:1048775007781736576【USDC】:306545790829【ETH】:50272966235836838313984
# 将要投入池子的数量 amount_t0: 306545790828 amount_t1: 50272966235836897034240
# 【RealWorldTime】:2021-07-26 06:55:55, Timestamp: 1627253755, Blocknumber: 12898232
# Mint position： Position(L=1048725890432304128, tick=[255420, 260460], range=[0.0489, 0.0809])
# 【Mint amount】: token0=3065.45790827, token1=50268.319660893816
# Wallet amount: token0=2e-08, token1=1650.6519422308038
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:7.8855642616494706
# Price(16.192060441470637) out of range(12.38207843991908, 20.588776118558645)
# 【RealWorldTime】:2021-07-26 08:59:57,Timestamp: 1627261197, Blocknumber: 12898769
# Decreased position： Position(L=0, tick=[255420, 260460], range=[0.0489, 0.0809])
# 【Decreased amount】: token0=2883.17766279, token1=53198.920915713956
# Wallet amount: token0=2883.17766281, token1=54849.57285794476
# 撤池后经转换 Wallet amount: token0=5599.99753685, token1=2716.5314343624104
# **********************【Price Over MA】【创建Long Vol池子】【第4次建池】***********************************
# 转换后钱包中余额 amount0:  251845889227.0 amount1:  45125547209657272739354
# price:  16.34926538490962
# $$$$$$$【Upper Price】: 21.08223905493527
# $$$$$$$【Lower Price】: 12.67884677380273
# ######【L】:870914805161301632【USDC】:251845889227【ETH】:42198384916465895604224
# 将要投入池子的数量 amount_t0: 251845889226 amount_t1: 42198384916465895604224
# 【RealWorldTime】:2021-07-26 19:02:45, Timestamp: 1627297365, Blocknumber: 12901461
# Mint position： Position(L=870326768014328320, tick=[255660, 260700], range=[0.0477, 0.0790])
# 【Mint amount】: token0=2518.45889225, token1=42142.09456020392
# Wallet amount: token0=2e-08, token1=2983.452649453349
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.708285506949132
# Price(16.719877986213977) out of range(12.67884677380273, 21.08223905493527)
# 【RealWorldTime】:2021-07-27 08:55:08,Timestamp: 1627347308, Blocknumber: 12905089
# Decreased position： Position(L=0, tick=[255660, 260700], range=[0.0477, 0.0790])
# 【Decreased amount】: token0=2277.1984787, token1=46130.504400434074
# Wallet amount: token0=2277.19847872, token1=49113.95704988742
# 撤池后经转换 Wallet amount: token0=4642.97006316, token1=2432.5218878077017
# **********************【Price Over MA】【创建Long Vol池子】【第5次建池】***********************************
# 转换后钱包中余额 amount0:  208805971167.0 amount1:  39633674948394481350633
# price:  16.898827152946957
# $$$$$$$【Upper Price】: 21.79089429395964
# $$$$$$$【Lower Price】: 13.105031638115765
# ######【L】:725873107980007808【USDC】:208805971167【ETH】:36149410388706555068416
# 将要投入池子的数量 amount_t0: 208805971167 amount_t1: 36149410388706555068416
# 【RealWorldTime】:2021-07-27 11:24:13, Timestamp: 1627356253, Blocknumber: 12905735
# Mint position： Position(L=725610347026107648, tick=[255960, 261060], range=[0.0460, 0.0766])
# 【Mint amount】: token0=2086.52945142, token1=36149.41038870656
# Wallet amount: token0=1.53026025, token1=3484.264559687926
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.5952861599152115
# Price(17.0902527053222) out of range(13.105031638115765, 21.79089429395964)
# 【RealWorldTime】:2021-07-28 08:33:20,Timestamp: 1627432400, Blocknumber: 12911280
# Decreased position： Position(L=0, tick=[255960, 261060], range=[0.0460, 0.0766])
# 【Decreased amount】: token0=1995.32016092, token1=37698.74625413546
# Wallet amount: token0=1996.85042117, token1=41183.01081382339
# 撤池后经转换 Wallet amount: token0=3966.71837034, token1=2039.7106062231765
# **********************【Price Over MA】【创建Long Vol池子】【第6次建池】***********************************
# 转换后钱包中余额 amount0:  178393241911.0 amount1:  33844538950604866170388
# price:  17.420389688285447
# $$$$$$$【Upper Price】: 22.463444759881686
# $$$$$$$【Lower Price】: 13.50950311208281
# ######【L】:630587484212261888【USDC】:178393241911【ETH】:31931280464637880958976
# 将要投入池子的数量 amount_t0: 178393241911 amount_t1: 31931280464637880958976
# 【RealWorldTime】:2021-07-28 14:57:55, Timestamp: 1627455475, Blocknumber: 12912987
# Mint position： Position(L=630394119709107584, tick=[256260, 261360], range=[0.0447, 0.0744])
# 【Mint amount】: token0=1782.82329383, token1=31931.280464637883
# Wallet amount: token0=1.10912528, token1=1913.2584859669853
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:15.338255063053154
# Price(17.24387669281463) out of range(13.50950311208281, 22.463444759881686)
# 【RealWorldTime】:2021-07-29 00:41:17,Timestamp: 1627490477, Blocknumber: 12915504
# Decreased position： Position(L=0, tick=[256260, 261360], range=[0.0447, 0.0744])
# 【Decreased amount】: token0=1863.42658032, token1=30534.61014930131
# Wallet amount: token0=1864.5357056, token1=32447.868635268293
# 撤池后经转换 Wallet amount: token0=3434.34894495, token1=1607.0521335839521
# **********************【Price Over MA】【创建Long Vol池子】【第7次建池】***********************************
# 转换后钱包中余额 amount0:  154451257928.0 amount1:  30315644680388589161289
# price:  17.180285227399064
# $$$$$$$【Upper Price】: 22.15383209390617
# $$$$$$$【Lower Price】: 13.323302227968787
# ######【L】:538584160367315520【USDC】:154451257928【ETH】:26908344777305493602304
# 将要投入池子的数量 amount_t0: 154451257928 amount_t1: 26908344777305493602304
# 【RealWorldTime】:2021-07-29 23:17:34, Timestamp: 1627571854, Blocknumber: 12921441
# Mint position： Position(L=538347750619394112, tick=[256140, 261240], range=[0.0452, 0.0753])
# 【Mint amount】: token0=1543.14715898, token1=26908.344777305494
# Wallet amount: token0=1.3654203, token1=3407.2999030830956
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.598934397016862
# Price(14.298318773631644) out of range(13.323302227968787, 22.15383209390617)
# 【RealWorldTime】:2021-08-11 21:26:37,Timestamp: 1628688397, Blocknumber: 13004163
# Decreased position： Position(L=0, tick=[256140, 261240], range=[0.0452, 0.0753])
# 【Decreased amount】: token0=2785.87656742, token1=7420.507773280855
# Wallet amount: token0=2787.24198772, token1=10827.807676363951
# 撤池后经转换 Wallet amount: token0=3483.14042066, token1=537.5633354678091
# **********************【Price Over MA】【创建Long Vol池子】【第8次建池】***********************************
# 转换后钱包中余额 amount0:  156645532569.0 amount1:  26673145011634535183074
# price:  15.033535331164677
# $$$$$$$【Upper Price】: 19.385616309400998
# $$$$$$$【Lower Price】: 11.658498803763855
# ######【L】:519643030619482112【USDC】:156645532569【ETH】:24152771485012089372672
# 将要投入池子的数量 amount_t0: 156645532568 amount_t1: 24152771485012118732800
# 【RealWorldTime】:2021-08-23 12:44:07, Timestamp: 1629693847, Blocknumber: 13079496
# Mint position： Position(L=519466563723103808, tick=[254820, 259860], range=[0.0519, 0.0859])
# 【Mint amount】: token0=1566.45532567, token1=24136.572683006165
# Wallet amount: token0=2e-08, token1=2536.57232862837
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:5.937236525245737
# Price(13.676939859392697) out of range(11.658498803763855, 19.385616309400998)
# 【RealWorldTime】:2021-09-08 06:42:23,Timestamp: 1631054543, Blocknumber: 13181399
# Decreased position： Position(L=0, tick=[254820, 259860], range=[0.0519, 0.0859])
# 【Decreased amount】: token0=2222.57842028, token1=14734.157406980425
# Wallet amount: token0=2222.5784203, token1=17270.729735608795
# 撤池后经转换 Wallet amount: token0=3354.41306209, token1=856.3659377999246
# **********************【Price Over MA】【创建Long Vol池子】【第9次建池】***********************************
# 转换后钱包中余额 amount0:  150856341436.0 amount1:  23433260594729706665379
# price:  13.841865494217123
# $$$$$$$【Upper Price】: 17.848968161266303
# $$$$$$$【Lower Price】: 10.734359467108025
# ######【L】:471999563532246144【USDC】:150856341436【ETH】:21158913880541041262592
# 将要投入池子的数量 amount_t0: 150856341435 amount_t1: 21158913880541099982848
# 【RealWorldTime】:2021-09-13 20:30:59, Timestamp: 1631536259, Blocknumber: 13217367
# Mint position： Position(L=470297272655783680, tick=[253980, 259080], range=[0.0561, 0.0934])
# 【Mint amount】: token0=1497.6118959, token1=21158.9138805411
# Wallet amount: token0=10.95151846, token1=2274.3467141886067
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:9.12684754166284
# Price(13.846456114772062) out of range(10.734359467108025, 17.848968161266303)
# 【RealWorldTime】:2021-09-13 21:54:47,Timestamp: 1631541287, Blocknumber: 13217733
# Decreased position： Position(L=0, tick=[253980, 259080], range=[0.0561, 0.0934])
# 【Decreased amount】: token0=1501.78694188, token1=21101.093951893432
# Wallet amount: token0=1512.73846034, token1=23375.44066608204
# 撤池后经转换 Wallet amount: token0=2951.63558162, token1=1157.6836995371941
# **********************【Price Over MA】【创建Long Vol池子】【第10次建池】***********************************
# 转换后钱包中余额 amount0:  132742431195.0 amount1:  20573836062346402925737
# price:  13.310553153306811
# $$$$$$$【Upper Price】: 17.16384540374796
# $$$$$$$【Lower Price】: 10.322327024008164
# ######【L】:411535979010123008【USDC】:132742431195【ETH】:18275112287404942163968
# 将要投入池子的数量 amount_t0: 132742431195 amount_t1: 18275112287404942163968
# 【RealWorldTime】:2021-09-16 16:59:31, Timestamp: 1631782771, Blocknumber: 13235838
# Mint position： Position(L=411199845727749120, tick=[253560, 258660], range=[0.0585, 0.0974])
# 【Mint amount】: token0=1325.21869541, token1=18275.112287404943
# Wallet amount: token0=2.20561654, token1=2298.7237749414608
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:5.139576329153009
# Price(13.2366151043541) out of range(10.322327024008164, 17.16384540374796)
# 【RealWorldTime】:2021-09-16 20:08:26,Timestamp: 1631794106, Blocknumber: 13236670
# Decreased position： Position(L=0, tick=[253560, 258660], range=[0.0585, 0.0974])
# 【Decreased amount】: token0=1351.58834534, token1=17924.898406501274
# Wallet amount: token0=1353.79396188, token1=20223.622181442734
# 撤池后经转换 Wallet amount: token0=2668.29842481, token1=1001.574888535952
# **********************【Price Over MA】【创建Long Vol池子】【第11次建池】***********************************
# 转换后钱包中余额 amount0:  120000050911.0 amount1:  19592133145535921065129
# price:  13.91338166043471
# $$$$$$$【Upper Price】: 17.94118765107184
# $$$$$$$【Lower Price】: 10.789820216687605
# ######【L】:375164325820170816【USDC】:120000050911【ETH】:16805506086011576254464
# 将要投入池子的数量 amount_t0: 120000050911 amount_t1: 16805506086011576254464
# 【RealWorldTime】:2021-09-18 08:48:06, Timestamp: 1631926086, Blocknumber: 13246586
# Mint position： Position(L=374061198329721088, tick=[254040, 259140], range=[0.0558, 0.0928])
# 【Mint amount】: token0=1192.92140972, token1=16805.506086011577
# Wallet amount: token0=7.07909939, token1=2786.627059524345
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.191873133313898
# Price(13.894557169059967) out of range(10.789820216687605, 17.94118765107184)
# 【RealWorldTime】:2021-09-18 14:35:09,Timestamp: 1631946909, Blocknumber: 13248097
# Decreased position： Position(L=0, tick=[254040, 259140], range=[0.0558, 0.0928])
# 【Decreased amount】: token0=1200.1402021, token1=16705.077965651322
# Wallet amount: token0=1207.21930149, token1=19491.705025175666
# 撤池后经转换 Wallet amount: token0=2429.39917968, token1=965.3277079111273
# **********************【Price Over MA】【创建Long Vol池子】【第12次建池】***********************************
# 转换后钱包中余额 amount0:  109256154609.0 amount1:  18063901657303114792399
# price:  13.910051440140311
# $$$$$$$【Upper Price】: 17.936893360245968
# $$$$$$$【Lower Price】: 10.787237632587242
# ######【L】:341288886881910784【USDC】:109256154609【ETH】:15275325500427790712832
# 将要投入池子的数量 amount_t0: 109256154609 amount_t1: 15275325500427790712832
# 【RealWorldTime】:2021-09-18 23:17:15, Timestamp: 1631978235, Blocknumber: 13250427
# Mint position： Position(L=340779125222533440, tick=[254040, 259140], range=[0.0558, 0.0928])
# 【Mint amount】: token0=1092.56154608, token1=15229.815121542457
# Wallet amount: token0=1e-08, token1=2834.0865357606576
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:5.248661508990914
# Price(14.01487437485828) out of range(10.787237632587242, 17.936893360245968)
# 【RealWorldTime】:2021-09-19 13:55:55,Timestamp: 1632030955, Blocknumber: 13254396
# Decreased position： Position(L=0, tick=[254040, 259140], range=[0.0558, 0.0928])
# 【Decreased amount】: token0=1055.84728628, token1=15742.36584170686
# Wallet amount: token0=1055.84728629, token1=18576.452377467518
# 撤池后经转换 Wallet amount: token0=2216.06852061, token1=920.0217881949028
# **********************【Price Over MA】【创建Long Vol池子】【第13次建池】***********************************
# 转换后钱包中余额 amount0:  99662141544.0 amount1:  16777221317212648361261
# price:  14.060221239503266
# $$$$$$$【Upper Price】: 18.13053604292721
# $$$$$$$【Lower Price】: 10.903694233624067
# ######【L】:318516569176824192【USDC】:99662141544【ETH】:14264226741988240654336
# 将要投入池子的数量 amount_t0: 99662141543 amount_t1: 14264226741988240654336
# 【RealWorldTime】:2021-09-19 18:52:38, Timestamp: 1632048758, Blocknumber: 13255710
# Mint position： Position(L=318071816309571264, tick=[254160, 259200], range=[0.0554, 0.0917])
# 【Mint amount】: token0=996.62141542, token1=14224.747770643455
# Wallet amount: token0=2e-08, token1=2552.473546569193
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False,arRollNorm:-34.89372570818878
# Price(14.27918345755578) out of range(10.903694233624067, 18.13053604292721)
# 【RealWorldTime】:2021-09-20 10:35:20,Timestamp: 1632105320, Blocknumber: 13260010
# Decreased position： Position(L=0, tick=[254160, 259200], range=[0.0554, 0.0917])
# 【Decreased amount】: token0=930.77380966, token1=15157.436923972171
# Wallet amount: token0=930.77380968, token1=17709.910470541363
# 撤池后经转换 Wallet amount: token0=2022.64540651, token1=877.1169417044737
# **********************【Price Over MA】【创建Long Vol池子】【第14次建池】***********************************
# 转换后钱包中余额 amount0:  90963420545.0 amount1:  16192579338061092533932
# price:  14.670530222564997
# $$$$$$$【Upper Price】: 18.91752430052549
# $$$$$$$【Lower Price】: 11.376988531486358
# ######【L】:297518921085786432【USDC】:90963420545【ETH】:13635111298278025592832
# 将要投入池子的数量 amount_t0: 90963420545 amount_t1: 13635111298278025592832
# 【RealWorldTime】:2021-10-01 22:46:24, Timestamp: 1633099584, Blocknumber: 13334105
# Mint position： Position(L=297475600667986368, tick=[254580, 259620], range=[0.0531, 0.0880])
# 【Mint amount】: token0=909.63420545, token1=13631.183053231363
# Wallet amount: token0=0.0, token1=2561.396284829729
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: True, VolHigherQuantile50TwoSigma: False,arRollNorm:-17.75400048823981
# Price(14.456248404761585) out of range(11.376988531486358, 18.91752430052549)
# 【RealWorldTime】:2021-10-02 09:18:26,Timestamp: 1633137506, Blocknumber: 13336884
# Decreased position： Position(L=0, tick=[254580, 259620], range=[0.0531, 0.0880])
# 【Decreased amount】: token0=967.87674301, token1=12783.188150059881
# Wallet amount: token0=967.87674301, token1=15344.58443488961
# 撤池后经转换 Wallet amount: token0=1925.07754342, token1=759.9438634242916
# **********************【Price Over MA】【创建Long Vol池子】【第15次建池】***********************************
# 转换后钱包中余额 amount0:  86575549822.0 amount1:  15275376484373873245654
# price:  14.502822343336936
# $$$$$$$【Upper Price】: 18.70126641259949
# $$$$$$$【Lower Price】: 11.246931158666744
# ######【L】:282075548868544416【USDC】:86575549822【ETH】:12876872557366282813440
# 将要投入池子的数量 amount_t0: 86575549822 amount_t1: 12876872557366282813440
# 【RealWorldTime】:2021-10-02 11:57:00, Timestamp: 1633147020, Blocknumber: 13337603
# Mint position： Position(L=281486223660805728, tick=[254460, 259500], range=[0.0538, 0.0890])
# 【Mint amount】: token0=865.75549822, token1=12823.745737483454
# Wallet amount: token0=0.0, token1=2451.6307468904183
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:8.537951947731557
# Price(16.26788695729792) out of range(11.246931158666744, 18.70126641259949)
# 【RealWorldTime】:2021-10-12 06:30:46,Timestamp: 1633991446, Blocknumber: 13399980
# Decreased position： Position(L=0, tick=[254460, 259500], range=[0.0538, 0.0890])
# 【Decreased amount】: token0=451.28006709, token1=19188.175609926788
# Wallet amount: token0=451.28006709, token1=21639.806356817207
# 撤池后经转换 Wallet amount: token0=1593.6922084, token1=1072.189246981757
# **********************【Price Over MA】【创建Long Vol池子】【第16次建池】***********************************
# 转换后钱包中余额 amount0:  71672322843.0 amount1:  14540646579403180033447
# price:  16.566335494189662
# $$$$$$$【Upper Price】: 21.362149119869848
# $$$$$$$【Lower Price】: 12.847184530266977
# ######【L】:245056674011032096【USDC】:71672322843【ETH】:12004993828323487383552
# 将要投入池子的数量 amount_t0: 71672322842 amount_t1: 12004993828323487383552
# 【RealWorldTime】:2021-10-12 19:17:46, Timestamp: 1634037466, Blocknumber: 13403291
# Mint position： Position(L=244790506911221856, tick=[255780, 260880], range=[0.0468, 0.0780])
# 【Mint amount】: token0=716.72322841, token1=11979.060209800346
# Wallet amount: token0=2e-08, token1=2561.5863696028346
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.692403546786963
# Price(15.389943708667786) out of range(12.847184530266977, 21.362149119869848)
# 【RealWorldTime】:2021-10-21 21:51:13,Timestamp: 1634824273, Blocknumber: 13461381
# Decreased position： Position(L=0, tick=[255780, 260880], range=[0.0468, 0.0780])
# 【Decreased amount】: token0=941.48713372, token1=8390.6535526986
# Wallet amount: token0=941.48713374, token1=10952.239922301436
# 撤池后经转换 Wallet amount: token0=1591.81927502, token1=542.9175183977634
# **********************【Price Over MA】【创建Long Vol池子】【第17次建池】***********************************
# 转换后钱包中余额 amount0:  71588092346.0 amount1:  13416921381492830698329
# price:  15.466792673226209
# $$$$$$$【Upper Price】: 19.944297977513
# $$$$$$$【Lower Price】: 11.99448964642847
# ######【L】:239429950229394336【USDC】:71588092346【ETH】:11469852132094144151552
# 将要投入池子的数量 amount_t0: 71588092345 amount_t1: 11469852132094144151552
# 【RealWorldTime】:2021-10-21 23:59:52, Timestamp: 1634831992, Blocknumber: 13461957
# Mint position： Position(L=238956354190063072, tick=[255060, 260160], range=[0.0503, 0.0838])
# 【Mint amount】: token0=712.9983489, token1=11469.852132094144
# Wallet amount: token0=2.88257456, token1=1947.0692493986865
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:6.983676486856119
# Price(15.417349694190262) out of range(11.99448964642847, 19.944297977513)
# 【RealWorldTime】:2021-10-22 00:59:01,Timestamp: 1634835541, Blocknumber: 13462227
# Decreased position： Position(L=0, tick=[255060, 260160], range=[0.0503, 0.0838])
# 【Decreased amount】: token0=723.02389812, token1=11314.975113057848
# Wallet amount: token0=725.90647268, token1=13262.044362456534
# 撤池后经转换 Wallet amount: token0=1517.80257537, token1=656.8031105873716
# **********************【Price Over MA】【创建Long Vol池子】【第18次建池】***********************************
# 转换后钱包中余额 amount0:  68259376322.0 amount1:  11961546743553391392576
# price:  14.125335755650852
# $$$$$$$【Upper Price】: 18.21450065926018
# $$$$$$$【Lower Price】: 10.954190506915193
# ######【L】:217603956209910272【USDC】:68259376322【ETH】:9936981517864609513472
# 将要投入池子的数量 amount_t0: 68259376321 amount_t1: 9936981517864609513472
# 【RealWorldTime】:2021-10-30 08:52:21, Timestamp: 1635555141, Blocknumber: 13515426
# Mint position： Position(L=217565324931602496, tick=[254160, 259260], range=[0.0551, 0.0917])
# 【Mint amount】: token0=682.5937632, token1=9933.505724659573
# Wallet amount: token0=2e-08, token1=2028.0410188938176
# ******************************************【撤销池子】【原因:OverMA与VolHigherQuantile50TwoSigma条件不满足】****************************
# CloseLowerMA: False, VolHigherQuantile50TwoSigma: False,arRollNorm:5.06546614230102
# Price(14.167488027362436) out of range(10.954190506915193, 18.21450065926018)
# 【RealWorldTime】:2021-10-30 10:59:23,Timestamp: 1635562763, Blocknumber: 13516006
# Decreased position： Position(L=0, tick=[254160, 259260], range=[0.0551, 0.0917])
# 【Decreased amount】: token0=673.85363215, token1=10057.143936320555
# Wallet amount: token0=673.85363217, token1=12085.184955214374
# 撤池后经转换 Wallet amount: token0=1451.67921338, token1=598.5218497704838
# **********************【Price Over MA】【创建Long Vol池子】【第19次建池】***********************************
# 转换后钱包中余额 amount0:  65285643425.0 amount1:  11505822514118473884747
# price:  14.207872628073916
# $$$$$$$【Upper Price】: 18.32093125625054
# $$$$$$$【Lower Price】: 11.018197808405745
# ######【L】:208572361795823968【USDC】:65285643425【ETH】:9545303193655672045568
# 将要投入池子的数量 amount_t0: 65285643425 amount_t1: 9545303193655684628480
# 【RealWorldTime】:2021-10-30 20:59:45, Timestamp: 1635598785, Blocknumber: 13518590
# Mint position： Position(L=208349920363111296, tick=[254220, 259320], range=[0.0548, 0.0912])
# 【Mint amount】: token0=652.85643424, token1=9525.23223569941
# Wallet amount: token0=1e-08, token1=1980.590278419063

# %% [markdown]
# # 获取原始绩效指标

# %%
positions = report.positions
positions
# Out:
# {1: <univ3api.simulation.PositionReport at 0x262688f6e20>,
#  2: <univ3api.simulation.PositionReport at 0x2627001efd0>,
#  3: <univ3api.simulation.PositionReport at 0x2626d476490>,
#  4: <univ3api.simulation.PositionReport at 0x2626d476af0>,
#  5: <univ3api.simulation.PositionReport at 0x2626d476f10>,
#  6: <univ3api.simulation.PositionReport at 0x2626ff55820>,
#  7: <univ3api.simulation.PositionReport at 0x2626ff55f70>,
#  8: <univ3api.simulation.PositionReport at 0x26264ce8280>,
#  9: <univ3api.simulation.PositionReport at 0x2626a18a6d0>,
#  10: <univ3api.simulation.PositionReport at 0x2626a045a00>,
#  11: <univ3api.simulation.PositionReport at 0x2626a045fa0>,
#  12: <univ3api.simulation.PositionReport at 0x2626a05a700>,
#  13: <univ3api.simulation.PositionReport at 0x2626a05ad60>,
#  14: <univ3api.simulation.PositionReport at 0x26269e2d580>,
#  15: <univ3api.simulation.PositionReport at 0x26269e2da60>,
#  16: <univ3api.simulation.PositionReport at 0x26269e2df40>,
#  17: <univ3api.simulation.PositionReport at 0x26269a371f0>,
#  18: <univ3api.simulation.PositionReport at 0x2626935d6d0>,
#  19: <univ3api.simulation.PositionReport at 0x2626935dd30>}

# %%
positions[5].get_balance(plain=True, draw_plot=True)
# Out:
#                datetime      amount0      fee0   cumFee0  collectedFee0  \
# 0   2021-07-27 11:24:13  2086.529451  0.000000  0.000000       0.000000
# 1   2021-07-27 12:10:48  2086.529127  0.000000  0.000000       0.000000
# 2   2021-07-27 12:14:33  2104.550831  0.009011  0.009011       0.009011
# 3   2021-07-27 12:31:50  2097.402033  0.000000  0.009011       0.009011
# 4   2021-07-27 12:46:20  2091.672979  0.000000  0.009011       0.009011
# ..                  ...          ...       ...       ...            ...
# 261 2021-07-28 08:21:13  2000.861401  0.000000  0.100218       0.100218
# 262 2021-07-28 08:21:45  1996.119147  0.000000  0.100218       0.100218
# 263 2021-07-28 08:21:45  1995.959436  0.000000  0.100218       0.100218
# 264 2021-07-28 08:33:20  1995.320161  0.000000  0.100218       0.100218
# 265 2021-07-28 08:33:20     0.000000 -0.100218  0.100218       0.000000
#
#           amount1      fee1   cumFee1  collectedFee1
# 0    36149.410389  0.000000  0.000000       0.000000
# 1    36149.415867  0.000003  0.000003       0.000003
# 2    35845.180823  0.000000  0.000003       0.000003
# 3    35965.789621  0.060304  0.060307       0.060307
# 4    36062.516124  0.048363  0.108670       0.108670
# ..            ...       ...       ...            ...
# 261  37604.160357  0.000025  2.416022       2.416022
# 262  37685.104322  0.040472  2.456494       2.456494
# 263  37687.831131  0.001363  2.457857       2.457857
# 264  37698.746254  0.005458  2.463315       2.463315
# 265           0.0 -2.463315  2.463315       0.000000
#
# [266 rows x 9 columns]

# %%
total_balance = report.total_balance(draw_plot=False, plain=True)
backtest_report = total_balance.copy(deep=True)

# %%
price = pricedata.drop_duplicates("timestamp").set_index("timestamp")["price"]
price
btc_balance = total_balance.set_index("timestamp")[["amount0NoFee", "cumFee0"]].sum(axis=1)
eth_balance = total_balance.set_index("timestamp")[["amount1NoFee", "cumFee1"]].sum(axis=1) / price
eth_balance+btc_balance
# eth_balance.plot()
# usdt_balance.plot()
tb_Timing = (eth_balance+btc_balance)
tb_Timing_origin = tb_Timing.copy(deep=True)
time_to_print = list(map(time.localtime,tb_Timing.index.tolist()))
time_to_print_2  = [time.strftime('%Y-%m-%d %H:%M:%S', i) for i in time_to_print]
# time_to_print_2  = [time.strftime('%Y-%m-%d', i) for i in time_to_print]
tb_Timing.index = time_to_print_2
tb_Timing.plot(rot = 45,grid=True,title='Total Balance')
# tb_Timing.to_csv('../../data/usdceth/tb_timing_v2.csv')
# tb_Timing_origin.to_csv('../../data/usdceth/tb_timing_origin_v2.csv')
# Out:
# <AxesSubplot:title={'center':'Total Balance'}>

# %%
eth_balance
eth_balance_df = pd.DataFrame(eth_balance)
eth_balance_df.columns = ['eth_balance']
eth_balance_df
# Out:
#             eth_balance
# timestamp
# 1620608457     0.000000
# 1620608592     0.000000
# 1620608683     0.000000
# 1620608715     0.000000
# 1620608967     0.000000
# ...                 ...
# 1636503509   799.213597
# 1636503788   799.560435
# 1636503867   799.768998
# 1636503933   800.591924
# 1636505218          NaN
#
# [40646 rows x 1 columns]

# %%
btc_balance
btc_balance_df = pd.DataFrame(btc_balance)
btc_balance_df.columns = ['btc_balance']
btc_balance_df
# Out:
#              btc_balance
# timestamp
# 1620608457  10000.000000
# 1620608592  10000.000000
# 1620608683  10000.000000
# 1620608715  10000.000000
# 1620608967  10000.000000
# ...                  ...
# 1636501511    670.043605
# 1636503509    668.878649
# 1636503788    668.391590
# 1636503867    668.098658
# 1636503933    666.942480
#
# [40645 rows x 1 columns]

# %%
tb_Timing
# Out:
# 2021-05-10 09:00:57    10000.000000
# 2021-05-10 09:03:12    10000.000000
# 2021-05-10 09:04:43    10000.000000
# 2021-05-10 09:05:15    10000.000000
# 2021-05-10 09:09:27    10000.000000
#                            ...
# 2021-11-10 08:18:29     1468.092245
# 2021-11-10 08:23:08     1467.952025
# 2021-11-10 08:24:27     1467.867657
# 2021-11-10 08:25:33     1467.534404
# 2021-11-10 08:46:58             NaN
# Length: 40646, dtype: float64

# %% [markdown]
# # 计算绩效指标

# %%
# tb_Timing.resample('D').sum()
pd.to_datetime(tb_Timing.index.tolist()[0])
tb_Timing.index = pd.to_datetime(tb_Timing.index)
tb_Timing.resample('D').last()
# Out:
# 2021-05-10    10000.000000
# 2021-05-11    10000.000000
# 2021-05-12    10000.000000
# 2021-05-13    10000.000000
# 2021-05-14    10000.000000
#                   ...
# 2021-11-06     1485.046506
# 2021-11-07     1504.174531
# 2021-11-08     1481.549658
# 2021-11-09     1474.996066
# 2021-11-10     1467.534404
# Freq: D, Length: 185, dtype: float64

# %%
df_tb = pd.DataFrame(tb_Timing.resample('D').last(),columns=['close'])
df_tb['return'] = df_tb['close'].pct_change()
df_tb['return_2'] = df_tb['close']/df_tb['close'].shift(1) - 1
df_tb = df_tb.iloc[:-1,:]
df_tb
# Out:
#                    close    return  return_2
# 2021-05-10  10000.000000       NaN       NaN
# 2021-05-11  10000.000000  0.000000  0.000000
# 2021-05-12  10000.000000  0.000000  0.000000
# 2021-05-13  10000.000000  0.000000  0.000000
# 2021-05-14  10000.000000  0.000000  0.000000
# ...                  ...       ...       ...
# 2021-11-05   1492.759852 -0.002337 -0.002337
# 2021-11-06   1485.046506 -0.005167 -0.005167
# 2021-11-07   1504.174531  0.012880  0.012880
# 2021-11-08   1481.549658 -0.015041 -0.015041
# 2021-11-09   1474.996066 -0.004423 -0.004423
#
# [184 rows x 3 columns]

# %%
df_tb['close'].plot()
# Out:
# <AxesSubplot:>

# %%
from scipy.stats.mstats import gmean
import math
def max_drawdown(df):
    """
    :return: Max drawdown of the financial series.
    """
    roll_max = df['close'].expanding().max()
    maxDrawdown = -1 * np.min(df['close'] / roll_max - 1)  # 计算得到最大回撤
    return maxDrawdown

def annual_return(df):
    """
    :return: Annual return.
    """
    annualReturn = gmean(df['return'].dropna() + 1) ** 365 - 1  # 得到年化收益率
    return annualReturn

def annual_std(df):
    """
    :return: The annual standard deviation.
    """
    dailyStd = df['return'].std()  # 得到日度波动率
    annualStd = dailyStd * math.sqrt(365)  # 得到年化波动率
    return annualStd

def sharpe_ratio(df):
    """
    :return:  Sharpe ratio.
    """
    annualReturn = annual_return(df)
    annualStd = annual_std(df)
    sharpeRatio = annualReturn / annualStd  # 得到夏普比
    return sharpeRatio

def calmar_ratio(df):
    """
    :return: Calmar ratio.
    """
    annualReturn = annual_return(df)
    maxDrawdown = max_drawdown(df)
    calmarRatio = annualReturn / maxDrawdown
    return calmarRatio

def max_drawdown_duration(df):
    """
    :return: Max Drawdown duration
    """
    xdate = df_tb.index.tolist()
    ycapital = df_tb['close'].tolist()
    duration = []
    tmp_max_capital = ycapital[0]
    for c in ycapital:
        if c >= tmp_max_capital:
            duration.append(0)
        else:
            duration.append(duration[-1]+1)
        tmp_max_capital = max(c, tmp_max_capital)
    MaxDDD = max(duration)
    endidx = np.argmax(duration)
    startidx = endidx - MaxDDD
#     print(xdate[startidx])
#     print(xdate[endidx])
    startD = xdate[startidx]
    endD = xdate[endidx]
#     return MaxDDD, startidx, endidx
    return MaxDDD, startD,endD

# %% [markdown]
# # 输出绩效

# %%
print('【SWAP_BTC_WETH_3000】')
print()

cumfee0 = backtest_report['cumFee0'].tolist()[-1]
cumfee1 = backtest_report['cumFee1'].tolist()[-1]/pricedata_res['price'].tolist()[-1]
print('BTC手续费',cumfee0,'ETH手续费(BTC计价)',cumfee1)
print('***************************资金曲线绩效***************************')
print('最大回撤',max_drawdown(df_tb))
print('最长回撤持续期',max_drawdown_duration(df_tb)[0],'日',
      '起始日期',max_drawdown_duration(df_tb)[1],
      '结束日期',max_drawdown_duration(df_tb)[2])
print('年化收益',annual_return(df_tb))
print('夏普比率',sharpe_ratio(df_tb))
print('卡尔玛比率',calmar_ratio(df_tb))
df_tb['close'].plot(title='Total Balance')
# Out:
# 【SWAP_BTC_WETH_3000】
#
# BTC手续费 5.08064274 ETH手续费(BTC计价) 4.830964813441977
# ***************************资金曲线绩效***************************
# 最大回撤 0.8547177009174858
# 最长回撤持续期 159 日 起始日期 2021-06-03 00:00:00 结束日期 2021-11-09 00:00:00
# 年化收益 -0.9780151326009746
# 夏普比率 -1.4605979627439818
# 卡尔玛比率 -1.1442551517900434
# <AxesSubplot:title={'center':'Total Balance'}>
